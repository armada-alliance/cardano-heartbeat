# %%
import json
import time
import requests
import math as m
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import descartes
import geopandas as gpd
from shapely.geometry import Point, Polygon
import seaborn as sns
from sklearn.preprocessing import StandardScaler
from sklearn.preprocessing import MinMaxScaler
from sklearn.cluster import KMeans
from sklearn.model_selection import train_test_split 
from sklearn.linear_model import LinearRegression
from sklearn import metrics
from scipy.optimize import curve_fit
import plotly.express as px
import chart_studio
import chart_studio.plotly as py
import chart_studio.tools as tls
import folium
import ast


# Leave This code here and lookup at pandas documentation 
# if you need to know about chained assignments
pd.options.mode.chained_assignment = None  # default='warn'

# Because most of my data sets I have made can have up to 30+ columns and 20+ rows
# code below will increase pandas defaults for max rows 
# and columns that you can display in a Juptyer Notebook
pd.options.display.max_columns = 60
pd.options.display.max_rows = 100

# %%
df = pd.read_json('all_relay_data.json')

# %% [markdown]
# ### Missing Data
#
# Alright, we need to do something about the missing data in the dataframe. Currently we have replaced the NaN values in the dataset with an empty string. This is going to be fine for handling this data, but it is not going to be fine for the actual missing data fetched from the IP Stack API. So there are a few reasons IP Stack API is not able to fetch data here is some information about the [IP Stack possible error codes](https://ipstack.com/documentation).
#
# There seems to be one specific code that causes IP stack's API to not be able to retrieve any information about the IP address. This is the `{'code': 106, 'type': 'invalid_ip_address', 'info': 'The IP Address supplied is invalid.'}` error. So we need to handle this error.
#
# ### Possible solutions:
# 1. Handle the error in the IP Stack API python script I wrote to deal with these errors.
# 2. Clean the dataframe by removing the rows that have the error code.

# %% [markdown]
# so what I ended up doing is just looking for all the connection that were nan (floats) and then checked if the `len of the strings is < 2` and if it is then I removed that row from the dataset. Then I needed to replace the single quotes with double quotes in the connections column to utilize the json.loads function. After that the last step was to make a json file.

# %%
# create a copy of the dataframe for testing purposes
testing = df.copy()

# This is code below will create a list of indexes of rows with missing data to be dropped
def drop_list(df):

	drop_list = []

	for i in range(len(df)):
		if df.connection[i] is None or len(df.connection[i]) < 2:
			drop_list.append(i)

	return drop_list

# %%
testing.drop(testing.index[drop_list(df)], inplace=True)
testing
# Out:
#                            ip_host     port  \
# 0                     54.220.20.40   3002.0
# 1     relays.mainnet.stakenuts.com   3001.0
# 2              relay.zenithpool.io  31400.0
# 3                     95.183.53.20   6060.0
# 4                   95.217.222.194   6060.0
# ...                            ...      ...
# 5503                188.166.12.123     6000
# 5505                  46.101.17.79     6000
# 5506                   72.86.45.91     3001
# 5507               r1.jaguares.org     3001
# 5508               r2.jaguares.org     3002
#
#                                                 pool_id      live_stake  \
# 0     pool1z5uqdk7dzdxaae5633fqfcu2eqzy3a3rgtuvy087f...  49569650567271
# 1     pool1pu5jlj4q9w9jlxeu370a3c9myx47md5j5m2str0na...  19157905491154
# 2     pool1c8k78ny3xvsfgenhf4yzvpzwgzxmz0t0um0h2xnn2...    547697202732
# 3     pool1q80jjs53w0fx836n8g38gtdwr8ck5zre3da90peux...   1862316910352
# 4     pool1q80jjs53w0fx836n8g38gtdwr8ck5zre3da90peux...   1862316910352
# ...                                                 ...             ...
# 5503  pool1pxsvz3yy606zr6qnhl2snvgzhcwny74pqaa2uvrk7...       130027614
# 5505  pool1pxsvz3yy606zr6qnhl2snvgzhcwny74pqaa2uvrk7...       130027614
# 5506  pool1k7gvq974d55yqcs4g6xyx4wy2fdlf97pffwgesjfq...     18295901333
# 5507  pool1wz5klzzjstlzmqgv55q8zwaxfxvyjyjhq49u9hg3f...     10008229492
# 5508  pool1wz5klzzjstlzmqgv55q8zwaxfxvyjyjhq49u9hg3f...     10008229492
#
#       delegators                                        description  \
# 0           3340                            Octa's Performance Pool
# 1            165                                      StakeNuts.com
# 2              9  One owner, one operator, one pool. Operating s...
# 3            707  Stability, Security, Reliability, Neutrality! ...
# 4            707  Stability, Security, Reliability, Neutrality! ...
# ...          ...                                                ...
# 5503           1  midnort staking pool, your nordic Cardano Stak...
# 5505           1  midnort staking pool, your nordic Cardano Stak...
# 5506           1                                               None
# 5507           1                                               None
# 5508           1                                               None
#
#                                                    hash  \
# 0     ca7d12decf886e31f5226b5946c62edc81a7e40af95ce7...
# 1     47c0c68cb57f4a5b4a87bad896fc274678e7aea98e200f...
# 2     21cc44498ab6e74e081a805e629fff171a66d0c8d034f9...
# 3     34fdde237812fab14d29a80423bb295f39122f4fea1aae...
# 4     34fdde237812fab14d29a80423bb295f39122f4fea1aae...
# ...                                                 ...
# 5503  cb738f574938eaa9e960e052f071bfb62e19950e1f3acf...
# 5505  cb738f574938eaa9e960e052f071bfb62e19950e1f3acf...
# 5506  92cf348da2c6a2a0666196009b4eb97101d3231955fd84...
# 5507  0915cb165e3532496e7183fce748827ac1f1aceebec819...
# 5508  0915cb165e3532496e7183fce748827ac1f1aceebec819...
#
#                                                     hex  \
# 0     153806dbcd134ddee69a8c5204e38ac80448f62342f8c2...
# 1     0f292fcaa02b8b2f9b3c8f9fd8e0bb21abedb692a6d505...
# 2     c1ede3cc9133209466774d4826044e408db13d6fe6df75...
# 3     01df29429173d263c7533a22742dae19f16a08798b7a57...
# 4     01df29429173d263c7533a22742dae19f16a08798b7a57...
# ...                                                 ...
# 5503  09a0c14484d3f421e813bfd509b102be1d327aa1077aae...
# 5505  09a0c14484d3f421e813bfd509b102be1d327aa1077aae...
# 5506  b790c017d56d28406215468c4355c4525bf497c14a5c8c...
# 5507  70a96f885282fe2d810ca500713ba64998491257054bc2...
# 5508  70a96f885282fe2d810ca500713ba64998491257054bc2...
#
#                                         homepage                    name  \
# 0                    https://octaluso.dyndns.org               OctasPool
# 1                         https://stakenuts.com/               StakeNuts
# 2                          https://zenithpool.io                  ZENITH
# 3                           https://ispool.live/  Switzerland Investment
# 4                           https://ispool.live/  Switzerland Investment
# ...                                          ...                     ...
# 5503  https://cryptoginger29.wixsite.com/midnort             midnort-ada
# 5505  https://cryptoginger29.wixsite.com/midnort             midnort-ada
# 5506                                        None                    None
# 5507                                        None                    None
# 5508                                        None                    None
#
#      ticker                                                url  \
# 0     OCTAS  https://raw.githubusercontent.com/Octalus/card...
# 1      NUTS                 https://stakenuts.com/mainnet.json
# 2       ZEN                     https://metadata.zenithpool.io
# 3       000                       https://ispool.live/metadata
# 4       000                       https://ispool.live/metadata
# ...     ...                                                ...
# 5503   MIDN                               https://git.io/JKN8b
# 5505   MIDN                               https://git.io/JKN8b
# 5506   None                               https://git.io/J6rex
# 5507   None                               https://git.io/J62wR
# 5508   None                               https://git.io/J62wR
#
#          resolved_ip               city  \
# 0       54.220.20.40             Dublin
# 1     199.247.23.219  Frankfurt am Main
# 2     193.122.12.254            Seattle
# 3       95.183.53.20             Zürich
# 4     95.217.222.194            Tuusula
# ...              ...                ...
# 5503  188.166.12.123             Diemen
# 5505    46.101.17.79         Blackheath
# 5506     72.86.45.91            Ashburn
# 5507   64.29.151.221          Rosemount
# 5508   64.29.151.221          Rosemount
#
#                                              connection country_code  \
# 0              {'asn': 16509, 'isp': 'amazon.com, Inc'}           IE
# 1     {'asn': 20473, 'isp': 'The Constant Company LLC'}           DE
# 2           {'asn': 31898, 'isp': 'Oracle Corporation'}           US
# 3     {'asn': 197988, 'isp': 'Solar Communications G...           CH
# 4          {'asn': 24940, 'isp': 'Hetzner Online Gmbh'}           FI
# ...                                                 ...          ...
# 5503          {'asn': 14061, 'isp': 'Digitalocean LLC'}           NL
# 5505          {'asn': 14061, 'isp': 'Digitalocean LLC'}           GB
# 5506  {'asn': 701, 'isp': 'Mci Communications Servic...           US
# 5507  {'asn': 30447, 'isp': 'internetnamesforbusines...           US
# 5508  {'asn': 30447, 'isp': 'internetnamesforbusines...           US
#
#         country_name   latitude   longitude region_code    region_name    zip  \
# 0            Ireland  53.353889   -6.243330           L       Leinster   None
# 1            Germany  50.113701    8.711900          HE          Hesse  60314
# 2      United States  47.611012 -122.333519          WA     Washington  98101
# 3        Switzerland  47.374168    8.536950          ZH         Zurich   8043
# 4            Finland  60.426418   25.011320          18        Uusimaa  04300
# ...              ...        ...         ...         ...            ...    ...
# 5503     Netherlands  52.309052    4.940190          NH  North Holland   1101
# 5505  United Kingdom  51.512218         NaN         ENG        England   EC2R
# 5506   United States  39.039570  -77.481613          VA       Virginia  20147
# 5507   United States  45.080059  -93.137718          MN      Minnesota  55126
# 5508   United States  45.080059  -93.137718          MN      Minnesota  55126
#
#      error  success detail
# 0     None      NaN   None
# 1     None      NaN   None
# 2     None      NaN   None
# 3     None      NaN   None
# 4     None      NaN   None
# ...    ...      ...    ...
# 5503  None      NaN   None
# 5505  None      NaN   None
# 5506  None      NaN   None
# 5507  None      NaN   None
# 5508  None      NaN   None
#
# [5253 rows x 25 columns]

# %%
len(df.connection[0])
# Out:
# 2

# %%
# Need to replace the single quotes with double quotes in the dataframe column connection 
# in order to be able to use the json.loads function later on

# testing.connection = testing.connection.replace({'\'': '"'}, regex=True)

# %%
# Read in the data from the json file using the json.loads function
# This will create a string with the correct format for which we can make into a dataframe

# data = json.load(open('relay_data_clean.json'))
# data = pd.DataFrame(data)
# data.connection[0]

# %%
# This is the code to create a list of dict from the list of json string

# def json_to_lst_dicts(data):
# 	lst = []
# 	for i in range(len(data)):
# 		if len(data['connection'][i]) > 0:
# 			result = json.loads(data['connection'][i])
# 			lst.append(result)
# 	return lst

# testing.connection = json_to_lst_dicts(data)

# %%
# Let's make sure it all worked as planned that when we attempt to check the connection column's
# entries type it is a dict

type(testing.connection[0])
# Out:
# dict

# %%
# Now we can easily grab (key, value) pairs from the connection column
testing.connection[0].get('isp')
# Out:
# 'amazon.com, Inc'

# %%
testing
# Out:
#                                dns dns_srv             ipv4 ipv6     port  \
# 0                              NaN     NaN     54.220.20.40  NaN   3002.0
# 1     relays.mainnet.stakenuts.com     NaN              NaN  NaN   3001.0
# 2              relay.zenithpool.io     NaN              NaN  NaN  31400.0
# 3                              NaN     NaN     95.183.53.20  NaN   6060.0
# 4                              NaN     NaN   95.217.222.194  NaN   6060.0
# ...                            ...     ...              ...  ...      ...
# 5413                           NaN     NaN  137.184.178.161  NaN     6000
# 5414                           NaN     NaN     46.101.17.79  NaN     6000
# 5415                           NaN     NaN      72.86.45.91  NaN     3001
# 5416               r1.jaguares.org     NaN              NaN  NaN     3001
# 5417               r2.jaguares.org     NaN              NaN  NaN     3002
#
#           live_stake  delegators  \
# 0     49569650567271        3340
# 1     19157905491154         165
# 2       547697202732           9
# 3      1862316910352         707
# 4      1862316910352         707
# ...              ...         ...
# 5413       130027614           1
# 5414       130027614           1
# 5415     18295901333           1
# 5416     10008229492           1
# 5417     10008229492           1
#
#                                             description  \
# 0                               Octa's Performance Pool
# 1                                         StakeNuts.com
# 2     One owner, one operator, one pool. Operating s...
# 3     Stability, Security, Reliability, Neutrality! ...
# 4     Stability, Security, Reliability, Neutrality! ...
# ...                                                 ...
# 5413  midnort staking pool, your nordic Cardano Stak...
# 5414  midnort staking pool, your nordic Cardano Stak...
# 5415                                                NaN
# 5416                                                NaN
# 5417                                                NaN
#
#                                           metadata_hash  \
# 0     ca7d12decf886e31f5226b5946c62edc81a7e40af95ce7...
# 1     47c0c68cb57f4a5b4a87bad896fc274678e7aea98e200f...
# 2     21cc44498ab6e74e081a805e629fff171a66d0c8d034f9...
# 3     34fdde237812fab14d29a80423bb295f39122f4fea1aae...
# 4     34fdde237812fab14d29a80423bb295f39122f4fea1aae...
# ...                                                 ...
# 5413  cb738f574938eaa9e960e052f071bfb62e19950e1f3acf...
# 5414  cb738f574938eaa9e960e052f071bfb62e19950e1f3acf...
# 5415  92cf348da2c6a2a0666196009b4eb97101d3231955fd84...
# 5416  0915cb165e3532496e7183fce748827ac1f1aceebec819...
# 5417  0915cb165e3532496e7183fce748827ac1f1aceebec819...
#
#                                             pool_id_hex  \
# 0     153806dbcd134ddee69a8c5204e38ac80448f62342f8c2...
# 1     0f292fcaa02b8b2f9b3c8f9fd8e0bb21abedb692a6d505...
# 2     c1ede3cc9133209466774d4826044e408db13d6fe6df75...
# 3     01df29429173d263c7533a22742dae19f16a08798b7a57...
# 4     01df29429173d263c7533a22742dae19f16a08798b7a57...
# ...                                                 ...
# 5413  09a0c14484d3f421e813bfd509b102be1d327aa1077aae...
# 5414  09a0c14484d3f421e813bfd509b102be1d327aa1077aae...
# 5415  b790c017d56d28406215468c4355c4525bf497c14a5c8c...
# 5416  70a96f885282fe2d810ca500713ba64998491257054bc2...
# 5417  70a96f885282fe2d810ca500713ba64998491257054bc2...
#
#                                         homepage                    name  \
# 0                    https://octaluso.dyndns.org               OctasPool
# 1                         https://stakenuts.com/               StakeNuts
# 2                          https://zenithpool.io                  ZENITH
# 3                           https://ispool.live/  Switzerland Investment
# 4                           https://ispool.live/  Switzerland Investment
# ...                                          ...                     ...
# 5413  https://cryptoginger29.wixsite.com/midnort             midnort-ada
# 5414  https://cryptoginger29.wixsite.com/midnort             midnort-ada
# 5415                                         NaN                     NaN
# 5416                                         NaN                     NaN
# 5417                                         NaN                     NaN
#
#                                                 pool_id ticker  \
# 0     pool1z5uqdk7dzdxaae5633fqfcu2eqzy3a3rgtuvy087f...  OCTAS
# 1     pool1pu5jlj4q9w9jlxeu370a3c9myx47md5j5m2str0na...   NUTS
# 2     pool1c8k78ny3xvsfgenhf4yzvpzwgzxmz0t0um0h2xnn2...    ZEN
# 3     pool1q80jjs53w0fx836n8g38gtdwr8ck5zre3da90peux...    000
# 4     pool1q80jjs53w0fx836n8g38gtdwr8ck5zre3da90peux...    000
# ...                                                 ...    ...
# 5413  pool1pxsvz3yy606zr6qnhl2snvgzhcwny74pqaa2uvrk7...   MIDN
# 5414  pool1pxsvz3yy606zr6qnhl2snvgzhcwny74pqaa2uvrk7...   MIDN
# 5415  pool1k7gvq974d55yqcs4g6xyx4wy2fdlf97pffwgesjfq...    NaN
# 5416  pool1wz5klzzjstlzmqgv55q8zwaxfxvyjyjhq49u9hg3f...    NaN
# 5417  pool1wz5klzzjstlzmqgv55q8zwaxfxvyjyjhq49u9hg3f...    NaN
#
#                                                     url          ip host  \
# 0     https://raw.githubusercontent.com/Octalus/card...     54.220.20.40
# 1                    https://stakenuts.com/mainnet.json    198.13.62.211
# 2                        https://metadata.zenithpool.io  129.146.210.203
# 3                          https://ispool.live/metadata     95.183.53.20
# 4                          https://ispool.live/metadata   95.217.222.194
# ...                                                 ...              ...
# 5413                               https://git.io/JKN8b   23.147.229.150
# 5414                               https://git.io/JKN8b     104.21.75.11
# 5415                               https://git.io/J6rex    64.225.79.144
# 5416                               https://git.io/J62wR    161.35.90.165
# 5417                               https://git.io/J62wR  147.182.138.250
#
#              city                                         connection  \
# 0          Dublin           {'asn': 16509, 'isp': 'amazon.com, Inc'}
# 1        Kawasaki  {'asn': 20473, 'isp': 'The Constant Company LLC'}
# 2         Phoenix        {'asn': 31898, 'isp': 'Oracle Corporation'}
# 3          Zürich  {'asn': 197988, 'isp': 'Solar Communications G...
# 4         Tuusula       {'asn': 24940, 'isp': 'Hetzner Online Gmbh'}
# ...           ...                                                ...
# 5413    Ann Arbor                                                 {}
# 5414     San Jose                {'asn': 13335, 'isp': 'Cloudflare'}
# 5415      Atlanta          {'asn': 14061, 'isp': 'Digitalocean LLC'}
# 5416     Westford          {'asn': 14061, 'isp': 'Digitalocean LLC'}
# 5417  Kansas City          {'asn': 14061, 'isp': 'Digitalocean LLC'}
#
#      country_code   country_name   latitude   longitude region_code  \
# 0              IE        Ireland  53.353889   -6.243330           L
# 1              JP          Japan  35.583511  139.746155          14
# 2              US  United States  33.509380 -112.082550          AZ
# 3              CH    Switzerland  47.374168    8.536950          ZH
# 4              FI        Finland  60.426418   25.011320          18
# ...           ...            ...        ...         ...         ...
# 5413           US  United States  42.285641  -83.716728          MI
# 5414           US  United States  37.330528 -121.838226          CA
# 5415           US  United States  33.798458  -84.388283          GA
# 5416           US  United States  42.589001  -71.441742          MA
# 5417           US  United States  38.955070  -94.595131          MO
#
#         region_name       zip error  success detail
# 0          Leinster       NaN   NaN      NaN    NaN
# 1          Kanagawa  143-0006   NaN      NaN    NaN
# 2           Arizona     85013   NaN      NaN    NaN
# 3            Zurich      8043   NaN      NaN    NaN
# 4           Uusimaa     04300   NaN      NaN    NaN
# ...             ...       ...   ...      ...    ...
# 5413       Michigan     48109   NaN      NaN    NaN
# 5414     California     95122   NaN      NaN    NaN
# 5415        Georgia     30309   NaN      NaN    NaN
# 5416  Massachusetts     01886   NaN      NaN    NaN
# 5417       Missouri     64114   NaN      NaN    NaN
#
# [5266 rows x 28 columns]

# %% [markdown]
# We need to now make a new isp and asn column for our df...:)

# %%
# create the isp and asn columns by using the get function with
testing['isp'] = testing.connection.apply(lambda x: x.get('isp', np.nan))
testing['asn'] = testing.connection.apply(lambda x: x.get('asn', np.nan))
testing[testing['ticker'] == 'PIADA']
# Out:
#             ip_host  port                                            pool_id  \
# 3449  east.piada.io  3000  pool1hrv8gtrm0dgjg6zyss5uwa4nkruzfnh5vrdkr2say...
# 3450  east.piada.io  3002  pool1hrv8gtrm0dgjg6zyss5uwa4nkruzfnh5vrdkr2say...
#
#         live_stake  delegators  \
# 3449  207194064280          67
# 3450  207194064280          67
#
#                                             description  \
# 3449  PIADA provides educational content specializin...
# 3450  PIADA provides educational content specializin...
#
#                                                    hash  \
# 3449  b89a6afcc92714b580d5449b7691e81b3b8ac417cc664e...
# 3450  b89a6afcc92714b580d5449b7691e81b3b8ac417cc664e...
#
#                                                     hex  \
# 3449  b8d8742c7b7b512468448429c776b3b0f824cef460db61...
# 3450  b8d8742c7b7b512468448429c776b3b0f824cef460db61...
#
#                           homepage       name ticker  \
# 3449  https://tinyurl.com/3n6ftstn  𝛑 + ₳ = ∞  PIADA
# 3450  https://tinyurl.com/3n6ftstn  𝛑 + ₳ = ∞  PIADA
#
#                                        url   resolved_ip     city  \
# 3449  https://piada.io/piada.metadata.json  100.7.78.240  Bon Air
# 3450  https://piada.io/piada.metadata.json  100.7.78.240  Bon Air
#
#                                              connection country_code  \
# 3449  {'asn': 701, 'isp': 'Mci Communications Servic...           US
# 3450  {'asn': 701, 'isp': 'Mci Communications Servic...           US
#
#        country_name   latitude  longitude region_code region_name    zip  \
# 3449  United States  37.534168 -77.635902          VA    Virginia  23113
# 3450  United States  37.534168 -77.635902          VA    Virginia  23113
#
#      error  success detail                                                isp  \
# 3449  None      NaN   None  Mci Communications Services Inc. D/B/a Verizon...
# 3450  None      NaN   None  Mci Communications Services Inc. D/B/a Verizon...
#
#       asn
# 3449  701
# 3450  701

# %%
# Save this to a json file called "cleaned"
testing.to_json('relay_data_clean.json')

# %%
# create a df with num relays per ISP and graph it
num_relays_per_isp = testing.isp.value_counts()
top_100_isp = num_relays_per_isp.head(100)
top_100_isp.name = 'count'

# %%
top_100_isp = top_100_isp.reset_index().replace({'index': {'amazon.com Inc.':'amazon.com, Inc'}}).groupby('index', sort=False).sum().sort_values(by='count', ascending=False)
# top_100_isp.rename(columns={'ISP':'Number of Relays'}, inplace=True)

# %%
# fig = px.bar(top_100_isp, x=top_100_isp.index, y=top_100_isp['count'], color=top_100_isp.index, width=1200, height=800, title='Top 100 ISPs',
#              labels={'index': 'ISP', 'count': 'Number of Relays'})

# fig.update_yaxes(automargin=True)

# %%
# # Geo Scatter Plot of the relays
# testing.fillna('', inplace=True)
# fig = px.scatter_geo(testing,
#                      lat = 'latitude',
#                      lon = 'longitude',
#                 #      locationmode='country names',
#                 #      locations="city",
#                      color="pool_id_hex", # which column to use to set the color of markers
#                      hover_name="ticker", # column added to hover information
#                      hover_data = ['live_stake', 'city', 'connection', 'delegators'],
#                 #      size="delegators", # size of markers
#                      projection="natural earth")
# fig.show()

# %%
# fig = px.scatter(top_100_isp, x=top_100_isp.index, y=top_100_isp.values, color=top_100_isp.index, width=1200, height=800, title='Top 100 ISPs', size=top_100_isp.values, hover_name=top_100_isp.index,
#                 labels={'index':'ISP', 'y':'Number of Relays'},)
             

# fig.update_yaxes(automargin=True)

# %%
# fig = px.bar(top_100_isp, x=top_100_isp.index, y=top_100_isp.values, color=top_100_isp.index, width=1200, height=800, title='Top 100 ISPs',
#              labels={'index': 'ISP', 'y': 'Number of Relays'})

# fig.update_yaxes(automargin=True)

# %%
# live_stake_per_isp = testing.groupby('isp').live_stake.sum()/1000000
# live_stake_per_isp

# %%
# rslt_df = df_stake_isp[df_stake_isp['live_stake'] > 100000000]
# rslt_df.sum()

# %%
# df_stake_isp = live_stake_per_isp.sort_values(ascending=False).to_frame()

# fig = px.bar(rslt_df, x=rslt_df.index, y=rslt_df.live_stake.values, color=rslt_df.index, width=1500, height=800, title='Top ISPs with a controlled Stake > 1 Billion ADA',
# 	    labels={'y': 'ADA Staked'})

# fig.update_yaxes(automargin=True)

# %%
# cardano_total_stake = testing.live_stake.sum()/1000000
# print("Total Stake controlled in ADA: "+str(cardano_total_stake))

# percentage_of_total_stake = live_stake_per_isp/cardano_total_stake * 100
# percentage_of_total_stake.sort_values(ascending=False)

# %%
# percentage_of_total_stake_df = percentage_of_total_stake.to_frame()
# percentage_of_total_stake_df.sort_values(by='live_stake', ascending=False, inplace=True)
# top_pools = percentage_of_total_stake_df.where(percentage_of_total_stake_df.live_stake > 1).dropna()
# top_pools

# %%
# fig = px.pie(percentage_of_total_stake_df, values=percentage_of_total_stake.values, names=percentage_of_total_stake.index, title='Percentage of Total Stake controlled in ADA Per ISP',)

# fig.update_traces(textposition='inside', textinfo='percent+label')

# %%
# fig = px.pie(top_pools, values=top_pools.live_stake.values, names=top_pools.index, title='Breakdown of the Top ',)

# fig.update_traces(textposition='inside', textinfo='percent+label')

# %%
# live_stake_per_isp.replace('amazon.com\s\Inc.','amazon.com\s\Inc',regex=True, inplace = True)

# %% [markdown]
# ## Notes on what to do explore with the Data:
#
# - Would be nice to get accurate picture of how much ada is stake per isp. Right now the issue is running the `pd.DataFrame.column.sum()` function is the dataframe has relays with same live stake being added up. For example 1 pool has 3 realys and 1 isp, but do to the way the dataset is built the 3 relays have a live stake attached so the 1 pool's live stake is essentially 3 times the actual value of the pool's stake.
#
# - It would also be nice to know how many relays and individual pools per isp.

# %% [markdown]
# > ### Okay in this part let's attempt to get the right amount of ada staked in pools out of our dataframe which at the time of writing this it is about `23.5B` ada staked in pools. The approach I am going to take is going to be very simple. The goal is to make a new column we will call `ada_staked_per_pool`. In order to get this column we will just iterate through the rows and check if the previous row has the same pool_id or not, if it does not we will add the current rows live_stake value to  the new `ada_staked_per_pool` column, otherwise is the pool_id's are equal we will just add the current index to a drop_list to be dropped from the df.

# %% [markdown]
# Steps:
#
# 1. create a new df called `df_ada_staked_per_pool` from the copy of the original df.
#
# 2. create empty dataframe called tmp_df
#
# 2. create a new empty list called drop_indexes
#
# 3. Create a for loop or a lambda function with map or something to iterate through the rows of the df and check the rows

# %%
df_ada_staked_per_pool = testing.copy()

# %%
df_ada_staked_per_pool
# Out:
#                                dns dns_srv             ipv4 ipv6     port  \
# 0                                              54.220.20.40        3002.0
# 1     relays.mainnet.stakenuts.com                                 3001.0
# 2              relay.zenithpool.io                                31400.0
# 3                                              95.183.53.20        6060.0
# 4                                            95.217.222.194        6060.0
# ...                            ...     ...              ...  ...      ...
# 5413                                        137.184.178.161          6000
# 5414                                           46.101.17.79          6000
# 5415                                            72.86.45.91          3001
# 5416               r1.jaguares.org                                   3001
# 5417               r2.jaguares.org                                   3002
#
#           live_stake  delegators  \
# 0     49569650567271        3340
# 1     19157905491154         165
# 2       547697202732           9
# 3      1862316910352         707
# 4      1862316910352         707
# ...              ...         ...
# 5413       130027614           1
# 5414       130027614           1
# 5415     18295901333           1
# 5416     10008229492           1
# 5417     10008229492           1
#
#                                             description  \
# 0                               Octa's Performance Pool
# 1                                         StakeNuts.com
# 2     One owner, one operator, one pool. Operating s...
# 3     Stability, Security, Reliability, Neutrality! ...
# 4     Stability, Security, Reliability, Neutrality! ...
# ...                                                 ...
# 5413  midnort staking pool, your nordic Cardano Stak...
# 5414  midnort staking pool, your nordic Cardano Stak...
# 5415
# 5416
# 5417
#
#                                           metadata_hash  \
# 0     ca7d12decf886e31f5226b5946c62edc81a7e40af95ce7...
# 1     47c0c68cb57f4a5b4a87bad896fc274678e7aea98e200f...
# 2     21cc44498ab6e74e081a805e629fff171a66d0c8d034f9...
# 3     34fdde237812fab14d29a80423bb295f39122f4fea1aae...
# 4     34fdde237812fab14d29a80423bb295f39122f4fea1aae...
# ...                                                 ...
# 5413  cb738f574938eaa9e960e052f071bfb62e19950e1f3acf...
# 5414  cb738f574938eaa9e960e052f071bfb62e19950e1f3acf...
# 5415  92cf348da2c6a2a0666196009b4eb97101d3231955fd84...
# 5416  0915cb165e3532496e7183fce748827ac1f1aceebec819...
# 5417  0915cb165e3532496e7183fce748827ac1f1aceebec819...
#
#                                             pool_id_hex  \
# 0     153806dbcd134ddee69a8c5204e38ac80448f62342f8c2...
# 1     0f292fcaa02b8b2f9b3c8f9fd8e0bb21abedb692a6d505...
# 2     c1ede3cc9133209466774d4826044e408db13d6fe6df75...
# 3     01df29429173d263c7533a22742dae19f16a08798b7a57...
# 4     01df29429173d263c7533a22742dae19f16a08798b7a57...
# ...                                                 ...
# 5413  09a0c14484d3f421e813bfd509b102be1d327aa1077aae...
# 5414  09a0c14484d3f421e813bfd509b102be1d327aa1077aae...
# 5415  b790c017d56d28406215468c4355c4525bf497c14a5c8c...
# 5416  70a96f885282fe2d810ca500713ba64998491257054bc2...
# 5417  70a96f885282fe2d810ca500713ba64998491257054bc2...
#
#                                         homepage                    name  \
# 0                    https://octaluso.dyndns.org               OctasPool
# 1                         https://stakenuts.com/               StakeNuts
# 2                          https://zenithpool.io                  ZENITH
# 3                           https://ispool.live/  Switzerland Investment
# 4                           https://ispool.live/  Switzerland Investment
# ...                                          ...                     ...
# 5413  https://cryptoginger29.wixsite.com/midnort             midnort-ada
# 5414  https://cryptoginger29.wixsite.com/midnort             midnort-ada
# 5415
# 5416
# 5417
#
#                                                 pool_id ticker  \
# 0     pool1z5uqdk7dzdxaae5633fqfcu2eqzy3a3rgtuvy087f...  OCTAS
# 1     pool1pu5jlj4q9w9jlxeu370a3c9myx47md5j5m2str0na...   NUTS
# 2     pool1c8k78ny3xvsfgenhf4yzvpzwgzxmz0t0um0h2xnn2...    ZEN
# 3     pool1q80jjs53w0fx836n8g38gtdwr8ck5zre3da90peux...    000
# 4     pool1q80jjs53w0fx836n8g38gtdwr8ck5zre3da90peux...    000
# ...                                                 ...    ...
# 5413  pool1pxsvz3yy606zr6qnhl2snvgzhcwny74pqaa2uvrk7...   MIDN
# 5414  pool1pxsvz3yy606zr6qnhl2snvgzhcwny74pqaa2uvrk7...   MIDN
# 5415  pool1k7gvq974d55yqcs4g6xyx4wy2fdlf97pffwgesjfq...
# 5416  pool1wz5klzzjstlzmqgv55q8zwaxfxvyjyjhq49u9hg3f...
# 5417  pool1wz5klzzjstlzmqgv55q8zwaxfxvyjyjhq49u9hg3f...
#
#                                                     url          ip host  \
# 0     https://raw.githubusercontent.com/Octalus/card...     54.220.20.40
# 1                    https://stakenuts.com/mainnet.json    198.13.62.211
# 2                        https://metadata.zenithpool.io  129.146.210.203
# 3                          https://ispool.live/metadata     95.183.53.20
# 4                          https://ispool.live/metadata   95.217.222.194
# ...                                                 ...              ...
# 5413                               https://git.io/JKN8b   23.147.229.150
# 5414                               https://git.io/JKN8b     104.21.75.11
# 5415                               https://git.io/J6rex    64.225.79.144
# 5416                               https://git.io/J62wR    161.35.90.165
# 5417                               https://git.io/J62wR  147.182.138.250
#
#              city                                         connection  \
# 0          Dublin           {'asn': 16509, 'isp': 'amazon.com, Inc'}
# 1        Kawasaki  {'asn': 20473, 'isp': 'The Constant Company LLC'}
# 2         Phoenix        {'asn': 31898, 'isp': 'Oracle Corporation'}
# 3          Zürich  {'asn': 197988, 'isp': 'Solar Communications G...
# 4         Tuusula       {'asn': 24940, 'isp': 'Hetzner Online Gmbh'}
# ...           ...                                                ...
# 5413    Ann Arbor                                                 {}
# 5414     San Jose                {'asn': 13335, 'isp': 'Cloudflare'}
# 5415      Atlanta          {'asn': 14061, 'isp': 'Digitalocean LLC'}
# 5416     Westford          {'asn': 14061, 'isp': 'Digitalocean LLC'}
# 5417  Kansas City          {'asn': 14061, 'isp': 'Digitalocean LLC'}
#
#      country_code   country_name latitude longitude region_code  \
# 0              IE        Ireland  53.3539  -6.24333           L
# 1              JP          Japan  35.5835   139.746          14
# 2              US  United States  33.5094  -112.083          AZ
# 3              CH    Switzerland  47.3742   8.53695          ZH
# 4              FI        Finland  60.4264   25.0113          18
# ...           ...            ...      ...       ...         ...
# 5413           US  United States  42.2856  -83.7167          MI
# 5414           US  United States  37.3305  -121.838          CA
# 5415           US  United States  33.7985  -84.3883          GA
# 5416           US  United States   42.589  -71.4417          MA
# 5417           US  United States  38.9551  -94.5951          MO
#
#         region_name       zip error success detail                        isp  \
# 0          Leinster                                           amazon.com, Inc
# 1          Kanagawa  143-0006                        The Constant Company LLC
# 2           Arizona     85013                              Oracle Corporation
# 3            Zurich      8043                       Solar Communications Gmbh
# 4           Uusimaa     04300                             Hetzner Online Gmbh
# ...             ...       ...   ...     ...    ...                        ...
# 5413       Michigan     48109
# 5414     California     95122                                      Cloudflare
# 5415        Georgia     30309                                Digitalocean LLC
# 5416  Massachusetts     01886                                Digitalocean LLC
# 5417       Missouri     64114                                Digitalocean LLC
#
#          asn
# 0      16509
# 1      20473
# 2      31898
# 3     197988
# 4      24940
# ...      ...
# 5413
# 5414   13335
# 5415   14061
# 5416   14061
# 5417   14061
#
# [5266 rows x 30 columns]

# %%
df_ada_staked_per_pool = df_ada_staked_per_pool.drop_duplicates(subset=['pool_id'], keep='first')
df_ada_staked_per_pool
# Out:
#                                           dns dns_srv             ipv4 ipv6  \
# 0                                                         54.220.20.40
# 1                relays.mainnet.stakenuts.com
# 2                         relay.zenithpool.io
# 3                                                         95.183.53.20
# 5                                                      139.162.148.181
# ...                                       ...     ...              ...  ...
# 5407             relaynode1.thegroovynerd.com
# 5411  bushido-relays.mainnet.samurai-pool.net
# 5412                                                    188.166.12.123
# 5415                                                       72.86.45.91
# 5416                          r1.jaguares.org
#
#          port      live_stake  delegators  \
# 0      3002.0  49569650567271        3340
# 1      3001.0  19157905491154         165
# 2     31400.0    547697202732           9
# 3      6060.0   1862316910352         707
# 5      8088.0      4000924534          14
# ...       ...             ...         ...
# 5407     6000       144798771           1
# 5411     3001       509616990           1
# 5412     6000       130027614           1
# 5415     3001     18295901333           1
# 5416     3001     10008229492           1
#
#                                             description  \
# 0                               Octa's Performance Pool
# 1                                         StakeNuts.com
# 2     One owner, one operator, one pool. Operating s...
# 3     Stability, Security, Reliability, Neutrality! ...
# 5
# ...                                                 ...
# 5407  Stake pool for the advancement of STEM (Scienc...
# 5411  Righteousness, Sincerity and Loyalty are virtu...
# 5412  midnort staking pool, your nordic Cardano Stak...
# 5415
# 5416
#
#                                           metadata_hash  \
# 0     ca7d12decf886e31f5226b5946c62edc81a7e40af95ce7...
# 1     47c0c68cb57f4a5b4a87bad896fc274678e7aea98e200f...
# 2     21cc44498ab6e74e081a805e629fff171a66d0c8d034f9...
# 3     34fdde237812fab14d29a80423bb295f39122f4fea1aae...
# 5     79e7cf8d936bf0ced040516b288e2edc76f2f87af5400f...
# ...                                                 ...
# 5407  c7a6fc7a372ab238bd7e0206e4de521e216df68629e38a...
# 5411  45097dc6108b8d65c0e14a94683dca5ff4913e1dcd77fd...
# 5412  cb738f574938eaa9e960e052f071bfb62e19950e1f3acf...
# 5415  92cf348da2c6a2a0666196009b4eb97101d3231955fd84...
# 5416  0915cb165e3532496e7183fce748827ac1f1aceebec819...
#
#                                             pool_id_hex  \
# 0     153806dbcd134ddee69a8c5204e38ac80448f62342f8c2...
# 1     0f292fcaa02b8b2f9b3c8f9fd8e0bb21abedb692a6d505...
# 2     c1ede3cc9133209466774d4826044e408db13d6fe6df75...
# 3     01df29429173d263c7533a22742dae19f16a08798b7a57...
# 5     6b6164af70861c5537cc9c8e50fdae35139ca2c8c6fbb4...
# ...                                                 ...
# 5407  a9ec394d519fdc192707868c28f8285af37fe83c0c9ad4...
# 5411  6688aae2724cb038fa348b3cacba7e002b653cc41dda86...
# 5412  09a0c14484d3f421e813bfd509b102be1d327aa1077aae...
# 5415  b790c017d56d28406215468c4355c4525bf497c14a5c8c...
# 5416  70a96f885282fe2d810ca500713ba64998491257054bc2...
#
#                                         homepage                    name  \
# 0                    https://octaluso.dyndns.org               OctasPool
# 1                         https://stakenuts.com/               StakeNuts
# 2                          https://zenithpool.io                  ZENITH
# 3                           https://ispool.live/  Switzerland Investment
# 5
# ...                                          ...                     ...
# 5407                   https://thegroovynerd.com   The Groovy Nerds Pool
# 5411                    https://samurai-pool.net            Bushido Pool
# 5412  https://cryptoginger29.wixsite.com/midnort             midnort-ada
# 5415
# 5416
#
#                                                 pool_id ticker  \
# 0     pool1z5uqdk7dzdxaae5633fqfcu2eqzy3a3rgtuvy087f...  OCTAS
# 1     pool1pu5jlj4q9w9jlxeu370a3c9myx47md5j5m2str0na...   NUTS
# 2     pool1c8k78ny3xvsfgenhf4yzvpzwgzxmz0t0um0h2xnn2...    ZEN
# 3     pool1q80jjs53w0fx836n8g38gtdwr8ck5zre3da90peux...    000
# 5     pool1ddskftmsscw92d7vnj89pldwx5feegkgcmamgt5t0...
# ...                                                 ...    ...
# 5407  pool148krjn23nlwpjfc8s6xz37pgttehl6pupjddg4q6e...  GNERD
# 5411  pool1v6y24cnjfjcr37353v72ewn7qq4k20xyrhdgdd6sg...  BUSHI
# 5412  pool1pxsvz3yy606zr6qnhl2snvgzhcwny74pqaa2uvrk7...   MIDN
# 5415  pool1k7gvq974d55yqcs4g6xyx4wy2fdlf97pffwgesjfq...
# 5416  pool1wz5klzzjstlzmqgv55q8zwaxfxvyjyjhq49u9hg3f...
#
#                                                     url          ip host  \
# 0     https://raw.githubusercontent.com/Octalus/card...     54.220.20.40
# 1                    https://stakenuts.com/mainnet.json    198.13.62.211
# 2                        https://metadata.zenithpool.io  129.146.210.203
# 3                          https://ispool.live/metadata     95.183.53.20
# 5        https://pool.adascan.net/meta/v1/poolmeta.json  139.162.148.181
# ...                                                 ...              ...
# 5407                               https://git.io/JKPoj     146.158.31.5
# 5411         https://www.samurai-pool.net/metadata.json     65.102.12.19
# 5412                               https://git.io/JKN8b    45.92.126.202
# 5415                               https://git.io/J6rex    64.225.79.144
# 5416                               https://git.io/J62wR    161.35.90.165
#
#                    city                                         connection  \
# 0                Dublin           {'asn': 16509, 'isp': 'amazon.com, Inc'}
# 1              Kawasaki  {'asn': 20473, 'isp': 'The Constant Company LLC'}
# 2               Phoenix        {'asn': 31898, 'isp': 'Oracle Corporation'}
# 3                Zürich  {'asn': 197988, 'isp': 'Solar Communications G...
# 5     Frankfurt am Main                {'asn': 63949, 'isp': 'Linode LLC'}
# ...                 ...                                                ...
# 5407           Mariupol  {'asn': 35273, 'isp': 'Pe Serhii Leonidovich P...
# 5411           Portland  {'asn': 209, 'isp': 'Centurylink Communication...
# 5412             Dinuba                  {'asn': 35913, 'isp': 'Dedipath'}
# 5415            Atlanta          {'asn': 14061, 'isp': 'Digitalocean LLC'}
# 5416           Westford          {'asn': 14061, 'isp': 'Digitalocean LLC'}
#
#      country_code   country_name latitude longitude region_code  \
# 0              IE        Ireland  53.3539  -6.24333           L
# 1              JP          Japan  35.5835   139.746          14
# 2              US  United States  33.5094  -112.083          AZ
# 3              CH    Switzerland  47.3742   8.53695          ZH
# 5              DE        Germany  50.1109    8.6821          HE
# ...           ...            ...      ...       ...         ...
# 5407           UA        Ukraine  47.0971   37.5434          14
# 5411           US  United States  45.4917  -122.774          OR
# 5412           US  United States  36.4877  -119.503          CA
# 5415           US  United States  33.7985  -84.3883          GA
# 5416           US  United States   42.589  -71.4417          MA
#
#         region_name       zip error success detail  \
# 0          Leinster
# 1          Kanagawa  143-0006
# 2           Arizona     85013
# 3            Zurich      8043
# 5             Hesse     60311
# ...             ...       ...   ...     ...    ...
# 5407        Donetsk     87527
# 5411         Oregon     97298
# 5412     California     93631
# 5415        Georgia     30309
# 5416  Massachusetts     01886
#
#                                   isp     asn
# 0                     amazon.com, Inc   16509
# 1            The Constant Company LLC   20473
# 2                  Oracle Corporation   31898
# 3           Solar Communications Gmbh  197988
# 5                          Linode LLC   63949
# ...                               ...     ...
# 5407  Pe Serhii Leonidovich Ponomarov   35273
# 5411   Centurylink Communications LLC     209
# 5412                         Dedipath   35913
# 5415                 Digitalocean LLC   14061
# 5416                 Digitalocean LLC   14061
#
# [2997 rows x 30 columns]

# %%
pools_per_isp = df_ada_staked_per_pool.groupby('isp').pool_id.nunique().to_frame()
pools_per_isp.rename(columns={'pool_id': 'Number of Pools'}, inplace=True)

# %%
ada_per_isp = (df_ada_staked_per_pool.groupby('isp').live_stake.sum()/1000000).to_frame()
ada_per_isp
# Out:
#                                            live_stake
# isp
#                                          2.877476e+08
# 1&1 Ionos Se                             4.346519e+08
# 1&1 Versatel Deutschland Gmbh            7.491568e+06
# 31173 Services Ab                        1.775868e+01
# A1$1AG                                   5.327795e+06
# ...                                               ...
# nazwa.pl sp.z.o.o.                       1.625940e+05
# netplus.ch Sa                            3.226819e+06
# tele2 Sverige Ab                         0.000000e+00
# th.papamichail Vainas - g.psaltakis g.p  3.339597e+06
# xs4all Internet Bv                       7.391246e+04
#
# [325 rows x 1 columns]

# %%
ada_per_isp = ada_per_isp.merge(pools_per_isp, left_index=True, right_index=True)

# %%
ada_per_isp
# Out:
#                                            live_stake  Number of Pools
# isp
#                                          2.877476e+08               50
# 1&1 Ionos Se                             4.346519e+08               54
# 1&1 Versatel Deutschland Gmbh            7.491568e+06                2
# 31173 Services Ab                        1.775868e+01                1
# A1$1AG                                   5.327795e+06                4
# ...                                               ...              ...
# nazwa.pl sp.z.o.o.                       1.625940e+05                1
# netplus.ch Sa                            3.226819e+06                2
# tele2 Sverige Ab                         0.000000e+00                1
# th.papamichail Vainas - g.psaltakis g.p  3.339597e+06                2
# xs4all Internet Bv                       7.391246e+04                1
#
# [325 rows x 2 columns]

# %%
# pools_per_isp = df_ada_staked_per_pool.groupby(['isp','live_stake'])['pool_id'].count().to_frame()
# pools_per_isp = pools_per_isp.sort_values(by='pool_id',ascending=False)
ada_per_isp_100mil = ada_per_isp[ada_per_isp['live_stake'] > 100000000]
ada_per_isp_100mil.sort_values(by='live_stake', ascending=False, inplace=True)
testdf = ada_per_isp_100mil.copy()
testdf.reset_index().replace({'isp': {'amazon.com Inc.':'amazon.com, Inc'}}).groupby('isp', sort=False).sum()
ada_per_isp_100mil =  ada_per_isp_100mil.reset_index().replace({'isp': {'amazon.com Inc.':'amazon.com, Inc'}}).groupby('isp', sort=False).sum()
ada_per_isp_100mil.rename(index={'': 'Unknown'}, inplace=True)
ada_per_isp_100mil
# Out:
#                                                       live_stake  \
# isp
# amazon.com, Inc                                     4.352034e+09
# Hetzner Online Gmbh                                 2.153576e+09
# Ovh Sas                                             1.982694e+09
# Digitalocean LLC                                    1.852929e+09
# Google LLC                                          1.560643e+09
# Contabo Gmbh                                        1.242989e+09
# Microsoft Corporation                               8.710173e+08
# The Constant Company LLC                            7.553152e+08
# Contabo Inc.                                        5.002857e+08
# Linode LLC                                          4.863186e+08
# 1&1 Ionos Se                                        4.346519e+08
# Liberty Global B.V.                                 3.497111e+08
# Unknown                                             2.877476e+08
# Netcup Gmbh                                         2.760364e+08
# Charter Communications                              2.251012e+08
# Optage Inc.                                         2.135545e+08
# Pe Adamanov Vv                                      1.991827e+08
# Tencent Building Kejizhongyi Avenue                 1.964841e+08
# Jsc Iot                                             1.851655e+08
# Comcast                                             1.695392e+08
# Att Services Inc                                    1.685870e+08
# Zen Internet Ltd                                    1.648459e+08
# Binariang Berhad                                    1.330072e+08
# Mci Communications Services Inc. D/B/a Verizon ...  1.256040e+08
# Contabo Asia Private Limited                        1.252667e+08
# Akamai International B.V.                           1.214682e+08
# Think Systems Uk Ltd                                1.180008e+08
# Telia Company Ab                                    1.116925e+08
# Tempest Hosting LLC                                 1.038769e+08
# Solar Communications Gmbh                           1.011445e+08
# Frontier Communications of America Inc.             1.000186e+08
#
#                                                     Number of Pools
# isp
# amazon.com, Inc                                                 470
# Hetzner Online Gmbh                                             246
# Ovh Sas                                                         133
# Digitalocean LLC                                                408
# Google LLC                                                      214
# Contabo Gmbh                                                    231
# Microsoft Corporation                                            96
# The Constant Company LLC                                         81
# Contabo Inc.                                                     78
# Linode LLC                                                       53
# 1&1 Ionos Se                                                     54
# Liberty Global B.V.                                              10
# Unknown                                                          50
# Netcup Gmbh                                                      33
# Charter Communications                                           10
# Optage Inc.                                                      11
# Pe Adamanov Vv                                                    3
# Tencent Building Kejizhongyi Avenue                               9
# Jsc Iot                                                           3
# Comcast                                                          25
# Att Services Inc                                                 20
# Zen Internet Ltd                                                 15
# Binariang Berhad                                                  4
# Mci Communications Services Inc. D/B/a Verizon ...               16
# Contabo Asia Private Limited                                     28
# Akamai International B.V.                                        20
# Think Systems Uk Ltd                                              3
# Telia Company Ab                                                  2
# Tempest Hosting LLC                                               4
# Solar Communications Gmbh                                         4
# Frontier Communications of America Inc.                          11

# %%
fig = px.bar(ada_per_isp_100mil, x=ada_per_isp_100mil.index, y=ada_per_isp_100mil.live_stake.values, color=ada_per_isp_100mil.index, width=1500, height=800, title='Top ISPs by number of pools and stake',
	    labels={'y': 'ADA Staked'}, hover_data=['Number of Pools'])

fig.update_layout(xaxis_tickangle=-90)


fig.update_yaxes(automargin=True)

# %%
df_69 = testing.copy()

# %%
occurrences = df_69.groupby(['isp']).size().to_frame()
occurrences.rename(columns={0:'Number of Relays'}, inplace=True)
occurrences.sort_values(by='Number of Relays', ascending=False, inplace=True)
occurrences
# Out:
#                                    Number of Relays
# isp
# Digitalocean LLC                                706
# amazon.com, Inc                                 653
# Hetzner Online Gmbh                             449
# Contabo Gmbh                                    397
# Google LLC                                      341
# ...                                             ...
# Siel Informacijske Resitve d.o.o.                 1
# Siminn Hf                                         1
# Digi Spain Telecom s.l.u.                         1
# Singtel Fibre Broadband                           1
# Everyware Ag                                      1
#
# [420 rows x 1 columns]

# %%
# df_69.sort_values(by='hex', ascending=False, inplace=True)
# df_69

# %%
occurrences.sort_values(by='Number of Relays', ascending=False, inplace=True)

# %%
occurrences.rename(index={'': 'Unknown'}, inplace=True)

# %%
top_isps = ada_per_isp_100mil.index.to_list()

# %%
occurrences.drop(top_isps, inplace=True)

# %%
occurrences.sort_values(by='Number of Relays', ascending=False, inplace=True)

# %%
occurrences
# Out:
#                                    Number of Relays
# isp
# amazon.com Inc.                                 121
# Akamai Technologies Inc.                         51
# Strato Ag                                        37
# Charter Communications Inc                       31
# Sakura Internet Inc.                             24
# ...                                             ...
# Delta Fiber Nederland B.V.                        1
# Siel Informacijske Resitve d.o.o.                 1
# Siminn Hf                                         1
# Digi Spain Telecom s.l.u.                         1
# Everyware Ag                                      1
#
# [389 rows x 1 columns]

# %% [markdown]
# # Using DNSpython to reolve hostnames to IP addresses

# %%
import dns.resolver

result = dns.resolver.resolve('east.piada.io', 'A')

for val in result:
    print('A Record : ', val.to_text())
# Out:
# A Record :  100.7.78.240

# %%
data
# Out:
#                            ip_host     port  \
# 0                     54.220.20.40   3002.0
# 1     relays.mainnet.stakenuts.com   3001.0
# 2              relay.zenithpool.io  31400.0
# 3                     95.183.53.20   6060.0
# 4                   95.217.222.194   6060.0
# ...                            ...      ...
# 5504               137.184.178.161     6000
# 5505                  46.101.17.79     6000
# 5506                   72.86.45.91     3001
# 5507               r1.jaguares.org     3001
# 5508               r2.jaguares.org     3002
#
#                                                 pool_id      live_stake  \
# 0     pool1z5uqdk7dzdxaae5633fqfcu2eqzy3a3rgtuvy087f...  49569650567271
# 1     pool1pu5jlj4q9w9jlxeu370a3c9myx47md5j5m2str0na...  19157905491154
# 2     pool1c8k78ny3xvsfgenhf4yzvpzwgzxmz0t0um0h2xnn2...    547697202732
# 3     pool1q80jjs53w0fx836n8g38gtdwr8ck5zre3da90peux...   1862316910352
# 4     pool1q80jjs53w0fx836n8g38gtdwr8ck5zre3da90peux...   1862316910352
# ...                                                 ...             ...
# 5504  pool1pxsvz3yy606zr6qnhl2snvgzhcwny74pqaa2uvrk7...       130027614
# 5505  pool1pxsvz3yy606zr6qnhl2snvgzhcwny74pqaa2uvrk7...       130027614
# 5506  pool1k7gvq974d55yqcs4g6xyx4wy2fdlf97pffwgesjfq...     18295901333
# 5507  pool1wz5klzzjstlzmqgv55q8zwaxfxvyjyjhq49u9hg3f...     10008229492
# 5508  pool1wz5klzzjstlzmqgv55q8zwaxfxvyjyjhq49u9hg3f...     10008229492
#
#       delegators                                        description  \
# 0           3340                            Octa's Performance Pool
# 1            165                                      StakeNuts.com
# 2              9  One owner, one operator, one pool. Operating s...
# 3            707  Stability, Security, Reliability, Neutrality! ...
# 4            707  Stability, Security, Reliability, Neutrality! ...
# ...          ...                                                ...
# 5504           1  midnort staking pool, your nordic Cardano Stak...
# 5505           1  midnort staking pool, your nordic Cardano Stak...
# 5506           1                                               None
# 5507           1                                               None
# 5508           1                                               None
#
#                                                    hash  \
# 0     ca7d12decf886e31f5226b5946c62edc81a7e40af95ce7...
# 1     47c0c68cb57f4a5b4a87bad896fc274678e7aea98e200f...
# 2     21cc44498ab6e74e081a805e629fff171a66d0c8d034f9...
# 3     34fdde237812fab14d29a80423bb295f39122f4fea1aae...
# 4     34fdde237812fab14d29a80423bb295f39122f4fea1aae...
# ...                                                 ...
# 5504  cb738f574938eaa9e960e052f071bfb62e19950e1f3acf...
# 5505  cb738f574938eaa9e960e052f071bfb62e19950e1f3acf...
# 5506  92cf348da2c6a2a0666196009b4eb97101d3231955fd84...
# 5507  0915cb165e3532496e7183fce748827ac1f1aceebec819...
# 5508  0915cb165e3532496e7183fce748827ac1f1aceebec819...
#
#                                                     hex  \
# 0     153806dbcd134ddee69a8c5204e38ac80448f62342f8c2...
# 1     0f292fcaa02b8b2f9b3c8f9fd8e0bb21abedb692a6d505...
# 2     c1ede3cc9133209466774d4826044e408db13d6fe6df75...
# 3     01df29429173d263c7533a22742dae19f16a08798b7a57...
# 4     01df29429173d263c7533a22742dae19f16a08798b7a57...
# ...                                                 ...
# 5504  09a0c14484d3f421e813bfd509b102be1d327aa1077aae...
# 5505  09a0c14484d3f421e813bfd509b102be1d327aa1077aae...
# 5506  b790c017d56d28406215468c4355c4525bf497c14a5c8c...
# 5507  70a96f885282fe2d810ca500713ba64998491257054bc2...
# 5508  70a96f885282fe2d810ca500713ba64998491257054bc2...
#
#                                         homepage                    name  \
# 0                    https://octaluso.dyndns.org               OctasPool
# 1                         https://stakenuts.com/               StakeNuts
# 2                          https://zenithpool.io                  ZENITH
# 3                           https://ispool.live/  Switzerland Investment
# 4                           https://ispool.live/  Switzerland Investment
# ...                                          ...                     ...
# 5504  https://cryptoginger29.wixsite.com/midnort             midnort-ada
# 5505  https://cryptoginger29.wixsite.com/midnort             midnort-ada
# 5506                                        None                    None
# 5507                                        None                    None
# 5508                                        None                    None
#
#      ticker                                                url  \
# 0     OCTAS  https://raw.githubusercontent.com/Octalus/card...
# 1      NUTS                 https://stakenuts.com/mainnet.json
# 2       ZEN                     https://metadata.zenithpool.io
# 3       000                       https://ispool.live/metadata
# 4       000                       https://ispool.live/metadata
# ...     ...                                                ...
# 5504   MIDN                               https://git.io/JKN8b
# 5505   MIDN                               https://git.io/JKN8b
# 5506   None                               https://git.io/J6rex
# 5507   None                               https://git.io/J62wR
# 5508   None                               https://git.io/J62wR
#
#           resolved_ip               city  \
# 0        54.220.20.40             Dublin
# 1      199.247.23.219  Frankfurt am Main
# 2      193.122.12.254            Seattle
# 3        95.183.53.20             Zürich
# 4      95.217.222.194            Tuusula
# ...               ...                ...
# 5504  137.184.178.161            Ashburn
# 5505     46.101.17.79         Blackheath
# 5506      72.86.45.91            Ashburn
# 5507    64.29.151.221          Rosemount
# 5508    64.29.151.221          Rosemount
#
#                                              connection country_code  \
# 0              {'asn': 16509, 'isp': 'amazon.com, Inc'}           IE
# 1     {'asn': 20473, 'isp': 'The Constant Company LLC'}           DE
# 2           {'asn': 31898, 'isp': 'Oracle Corporation'}           US
# 3     {'asn': 197988, 'isp': 'Solar Communications G...           CH
# 4          {'asn': 24940, 'isp': 'Hetzner Online Gmbh'}           FI
# ...                                                 ...          ...
# 5504                                                 {}           US
# 5505          {'asn': 14061, 'isp': 'Digitalocean LLC'}           GB
# 5506  {'asn': 701, 'isp': 'Mci Communications Servic...           US
# 5507  {'asn': 30447, 'isp': 'internetnamesforbusines...           US
# 5508  {'asn': 30447, 'isp': 'internetnamesforbusines...           US
#
#         country_name   latitude   longitude region_code region_name    zip  \
# 0            Ireland  53.353889   -6.243330           L    Leinster   None
# 1            Germany  50.113701    8.711900          HE       Hesse  60314
# 2      United States  47.611012 -122.333519          WA  Washington  98101
# 3        Switzerland  47.374168    8.536950          ZH      Zurich   8043
# 4            Finland  60.426418   25.011320          18     Uusimaa  04300
# ...              ...        ...         ...         ...         ...    ...
# 5504   United States  39.043701  -77.474197          VA    Virginia  20147
# 5505  United Kingdom  51.512218         NaN         ENG     England   EC2R
# 5506   United States  39.039570  -77.481613          VA    Virginia  20147
# 5507   United States  45.080059  -93.137718          MN   Minnesota  55126
# 5508   United States  45.080059  -93.137718          MN   Minnesota  55126
#
#      error  success detail
# 0     None      NaN   None
# 1     None      NaN   None
# 2     None      NaN   None
# 3     None      NaN   None
# 4     None      NaN   None
# ...    ...      ...    ...
# 5504  None      NaN   None
# 5505  None      NaN   None
# 5506  None      NaN   None
# 5507  None      NaN   None
# 5508  None      NaN   None
#
# [5509 rows x 25 columns]

# %%
data = pd.read_json('relay_data_clean.json')
df_ada_staked_per_pool = data.copy()
df_ada_staked_per_pool = df_ada_staked_per_pool.drop_duplicates(subset=['pool_id'], keep='first')
pools_per_isp = df_ada_staked_per_pool.groupby('isp').pool_id.nunique().to_frame()
pools_per_isp.rename(columns={'pool_id': 'Number of Pools'}, inplace=True)
ada_per_isp = (df_ada_staked_per_pool.groupby('isp').live_stake.sum()/1000000).to_frame()
ada_per_isp = ada_per_isp.merge(pools_per_isp, left_index=True, right_index=True)
ada_per_isp_100mil = ada_per_isp[ada_per_isp['live_stake'] > 100000000]
ada_per_isp_100mil.sort_values(by='live_stake', ascending=False, inplace=True)
ada_per_isp_100mil =  ada_per_isp_100mil.reset_index().replace({'isp': {'amazon.com Inc.':'amazon.com, Inc'}}).groupby('isp', sort=False).sum()
ada_per_isp_100mil.rename(index={'': 'Unknown'}, inplace=True)
num_relays_per_isp = data.groupby(['isp']).size().to_frame()
num_relays_per_isp.rename(columns={0:'Number of Relays'}, inplace=True)
top_100_isp = num_relays_per_isp.head(100)
top_100_isp = top_100_isp.reset_index().replace({'isp': {'amazon.com Inc.':'amazon.com, Inc'}}).groupby('isp', sort=False).sum()
top_100_isp.sort_values(by='Number of Relays', ascending=False, inplace=True)

top_100_isp
# Out:
#                                                  Number of Relays
# isp
# Digitalocean LLC                                              714
# Contabo Gmbh                                                  408
# Contabo Inc.                                                  147
# 1&1 Ionos Se                                                  102
# Contabo Asia Private Limited                                   53
# Akamai Technologies Inc.                                       44
# Akamai International B.V.                                      41
# Comcast                                                        41
# Att Services Inc                                               37
# Charter Communications Inc                                     29
# Bell Canada                                                    19
# Charter Communications                                         18
# British Telecommunications Plc                                 14
# Cloudflare                                                     12
# Cox Communications Inc.                                        11
# Centurylink Communications LLC                                  9
# Alibaba (Us) Technology Co. Ltd.                                9
# Aussie Broadband                                                9
# Datacamp Limited                                                6
# Deutsche Telekom Ag                                             6
# Cambrium It Services B.V.                                       5
# A1$1AG                                                          5
# Active 1 Gmbh                                                   5
# Bahnhof                                                         5
# Cogent Communications                                           5
# Binariang Berhad                                                5
# Data Communication Business Group                               4
# Digital Island Ltd                                              4
# Digi Tavkozlesi Es Szolgaltato Kft.                             4
# Cogeco Cable                                                    4
# Broadnet As                                                     3
# Aruba s.p.A.                                                    3
# 31173 Services Ab                                               3
# Egihosting                                                      3
# Altibox                                                         3
# Cablenet Communication Systems Ltd                              3
# Accelerated It Services & Consulting Gmbh                       3
# Colocrossing                                                    2
# Combahton Gmbh                                                  2
# City of Fort Collins                                            2
# Dade Pardazi Mobinhost Co Ltd                                   2
# Chinanet                                                        2
# Datacenter d.o.o.                                               2
# Digital Energy Technologies Ltd.                                2
# Dna Oyj                                                         2
# Ecom Chaco s.A.                                                 2
# Empresa De Telecomunicaciones De Cuba s.A.                      2
# Entanet International Limited                                   2
# Entel Chile s.A.                                                2
# Eonix Corporation                                               2
# Cik Telecom Inc                                                 2
# Equinix Asia Pacific                                            2
# 1&1 Versatel Deutschland Gmbh                                   2
# Aixit Gmbh                                                      2
# Aerux Llp                                                       2
# Asahi Net                                                       2
# Bulloch County Rural Telephone Cooperative Inc.                 2
# Bti Communications                                              2
# Dod Network Information Center                                  1
# Delta Fiber Nederland B.V.                                      1
# Administracion Nacional De Telecomunicaciones                   1
# Digi Spain Telecom s.l.u.                                       1
# Atria Convergence Technologies                                  1
# Asiatech Data Transmission Company                              1
# Arteria Networks Corporation                                    1
# Aptitude Internet Solutions                                     1
# Accuserv Inc                                                    1
# Dogado Gmbh                                                     1
# Dynu Systems Incorporated                                       1
# Dedipath                                                        1
# Amanah Tech Inc.                                                1
# Ellada Projects b.v. Trading as Netrouting                      1
# Akenes Sa                                                       1
# Enet Inc.                                                       1
# Afrihost (Pty) Ltd                                              1
# Epm Telecomunicaciones s.a. e.s.p.                              1
# Antaree Solutions s.r.o                                         1
# Avative Fiber                                                   1
# Datacity                                                        1
# Avonet s.r.o.                                                   1
# Cincinnati Bell Telephone Company LLC                           1
# Citic Telecom Cpc Netherlands B.V.                              1
# Ais Fibre                                                       1
# Cloud Host Pte Ltd                                              1
# Cablevision Systems Corp.                                       1
# Cloudi Nextgen Sl                                               1
# Cnc Bilisim Hizmetleri Ins San Tic Ltd Sti                      1
# Cable One Inc.                                                  1
# Bitcommand LLC                                                  1
# Access Communications Co-Operative Limited                      1
# Compaa Dominicana De Telfonos S. A.                             1
# Consolidated Communications                                     1
# Accelero Limited                                                1
# Bharti Airtel Ltd.                                              1
# Bezeq International-Ltd                                         1
# Best-Net s.r.o.                                                 1
# Ctc. Corp s.a. (Telefonica Empresas)                            1
# Belcloud Ltd                                                    1
# Axtel s.a.b. De c.V.                                            1
# Airwaynet a.s.                                                  1
