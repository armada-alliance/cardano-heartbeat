# %%
#Importing packages
#
# You can delete whatever package(s) you want..
#
import json
import time
import requests
import math as m
import pandas as pd
import numpy as np

# Leave This code here and lookup at pandas documentation 
# if you need to know about chained assignments
pd.options.mode.chained_assignment = None  # default='warn'

# Because most of my data sets I have made can have up to 30+ columns and 20+ rows
# code below will increase pandas defaults for max rows 
# and columns that you can display in a Juptyer Notebook
pd.options.display.max_columns = 60
pd.options.display.max_rows = 1000

# %%
# Get access token from file
with open('access_key.txt', 'r') as file:
    access_key = file.read().replace('\n', '')
access_key = access_key.split('=')[1]

# # Get the data from the API
url = 'http://api.ipstack.com/100.7.78.240?&fields=country_code,country_name,city,latitude,longitude'
payload = {'access_key': '{key}'.format(key=access_key)}
reqs = requests.get(url, params=payload).json()
reqs
# Out:
# {'longitude': -77.63590240478516,
#  'latitude': 37.5341682434082,
#  'city': 'Bon Air',
#  'country_name': 'United States',
#  'country_code': 'US'}

# %%
df = pd.read_json('blockfrost_pool_relay_info_latest.json')

# %%
df
# Out:
#                                                 pool_id  \
# 0     pool1z5uqdk7dzdxaae5633fqfcu2eqzy3a3rgtuvy087f...
# 1     pool1pu5jlj4q9w9jlxeu370a3c9myx47md5j5m2str0na...
# 2     pool1c8k78ny3xvsfgenhf4yzvpzwgzxmz0t0um0h2xnn2...
# 3     pool1q80jjs53w0fx836n8g38gtdwr8ck5zre3da90peux...
# 4     pool1q80jjs53w0fx836n8g38gtdwr8ck5zre3da90peux...
# ...                                                 ...
# 5549  pool1hjlqkwx604reu9q2azkmqp9ek7f5yy37qz662afzl...
# 5550  pool1wj2j9zfv9mly5m7ax5fen0r8rp7tjj9uyz5gnwmyf...
# 5551  pool1wj2j9zfv9mly5m7ax5fen0r8rp7tjj9uyz5gnwmyf...
# 5552  pool178jmsy6t03udg2urvckseyync6y2jkq26haj7vxtw...
# 5553  pool1324lgsmm6aqkyeamzxjkfhsk4v9qtkr5knyza2r8l...
#
#                                                     hex  \
# 0     153806dbcd134ddee69a8c5204e38ac80448f62342f8c2...
# 1     0f292fcaa02b8b2f9b3c8f9fd8e0bb21abedb692a6d505...
# 2     c1ede3cc9133209466774d4826044e408db13d6fe6df75...
# 3     01df29429173d263c7533a22742dae19f16a08798b7a57...
# 4     01df29429173d263c7533a22742dae19f16a08798b7a57...
# ...                                                 ...
# 5549  bcbe0b38da7d479e140ae8adb004b9b79342123e00b5a5...
# 5550  749522892c2efe4a6fdd351399bc67187cb948bc20a889...
# 5551  749522892c2efe4a6fdd351399bc67187cb948bc20a889...
# 5552  f1e5b8134b7c78d42b83662d0c9093c688a9580ad5fb2f...
# 5553  8aabf4437bd7416267bb11a564de16ab0a05d874b4c82e...
#
#                                                 vrf_key  blocks_minted  \
# 0     0220a5d08adbfe9554b52d7b2993be5892ac3ff340e674...           3972
# 1     b512cc7c1a8ba689c2d8fd27adfdbac2049a3f8f95c8b8...           1731
# 2     b8ba5f7dcbf17e95781e325114da46def1fa908435a27d...             74
# 3     b75115a1e4e32a33985fc720f3715f0e99617b448fbc36...            253
# 4     b75115a1e4e32a33985fc720f3715f0e99617b448fbc36...            253
# ...                                                 ...            ...
# 5549  9e2dd26107ad95ef05522e49879f4b2285811c0eaa504f...              0
# 5550  d646e0712fd9dd18655787607970bbc643f4beca617a40...              0
# 5551  d646e0712fd9dd18655787607970bbc643f4beca617a40...              0
# 5552  b35b88a9474161da1022efe756e23d771a6a8deb541a3a...              0
# 5553  5fac976d838f1432925e44e209c5a8a7ac91f56d3b8968...              0
#
#           live_stake     live_size  live_saturation  live_delegators  \
# 0     32797569479332  1.378547e-03     4.903471e-01             3198
# 1     19363531997705  8.138880e-04     2.894987e-01              168
# 2       558085506979  2.345740e-05     8.343778e-03               15
# 3      1845839071889  7.758430e-05     2.759662e-02              717
# 4      1845839071889  7.758430e-05     2.759662e-02              717
# ...              ...           ...              ...              ...
# 5549      1000000000  4.200000e-08     1.495070e-05                1
# 5550       616723251  2.590000e-08     9.220500e-06                2
# 5551       616723251  2.590000e-08     9.220500e-06                2
# 5552       589721212  2.480000e-08     8.816800e-06                2
# 5553        43761105  1.800000e-09     6.543000e-07                2
#
#         active_stake  active_size  declared_pledge   live_pledge  margin_cost  \
# 0     16401223192227     0.001247     100000000000  572478193547        0.009
# 1     18304506933371     0.001391     510000000000  561624278408        0.049
# 2       550355739333     0.000042      50100000000  552069493858        0.000
# 3      1195539828288     0.000091     200000000000  205479488742        0.005
# 4      1195539828288     0.000091     200000000000  205479488742        0.005
# ...              ...          ...              ...           ...          ...
# 5549               0     0.000000       1000000000    1000000000        1.000
# 5550               0     0.000000        100000000     509250920        0.010
# 5551               0     0.000000        100000000     509250920        0.010
# 5552               0     0.000000        500000000     542784694        0.000
# 5553               0     0.000000        100000000             0        0.150
#
#       fixed_cost                                     reward_account  \
# 0      340000000  stake1uy89kzrdlpaz5rzu8x95r4qnlpqhd3f8mf09edjp...
# 1      340000000  stake1u98nnlkvkk23vtvf9273uq7cph5ww6u2yq2389ps...
# 2      340000000  stake1uyx0ut5wc5nmu0tacjc9pyyahdyq5ujghwljkdxr...
# 3      340000000  stake1uxxsa2rlkv728pve3ks7kn7c6v68luagdjgwa0me...
# 4      340000000  stake1uxxsa2rlkv728pve3ks7kn7c6v68luagdjgwa0me...
# ...          ...                                                ...
# 5549   500000000  stake1u95ggvstszjdwm2hmtpvcscjvne6fcamk2mqx2u3...
# 5550   340000000  stake1u8gm2glyzm0wzzlfrnzp90y4sqc46eqta5fpyqq0...
# 5551   340000000  stake1u8gm2glyzm0wzzlfrnzp90y4sqc46eqta5fpyqq0...
# 5552   340000000  stake1u9c7ypc7swj7gultpv4dh2uhs3xc2dcdm9278mp7...
# 5553   345000000  stake1u884wym0uvcetx6lmjz4xm7kyvjvhejm7m3xyggw...
#
#                                                  owners  \
# 0     [stake1uy89kzrdlpaz5rzu8x95r4qnlpqhd3f8mf09edj...
# 1     [stake1u98nnlkvkk23vtvf9273uq7cph5ww6u2yq2389p...
# 2     [stake1uyx0ut5wc5nmu0tacjc9pyyahdyq5ujghwljkdx...
# 3     [stake1uxxsa2rlkv728pve3ks7kn7c6v68luagdjgwa0m...
# 4     [stake1uxxsa2rlkv728pve3ks7kn7c6v68luagdjgwa0m...
# ...                                                 ...
# 5549  [stake1u95ggvstszjdwm2hmtpvcscjvne6fcamk2mqx2u...
# 5550  [stake1u8gm2glyzm0wzzlfrnzp90y4sqc46eqta5fpyqq...
# 5551  [stake1u8gm2glyzm0wzzlfrnzp90y4sqc46eqta5fpyqq...
# 5552  [stake1u9c7ypc7swj7gultpv4dh2uhs3xc2dcdm9278mp...
# 5553  [stake1u884wym0uvcetx6lmjz4xm7kyvjvhejm7m3xygg...
#
#                                            registration retirement  \
# 0     [841cca81da918feb9fa7257a34630eac95794be712ed3...         []
# 1     [a96c79773b7506211eb56bf94886a2face17657d1009f...         []
# 2     [37f5682e2622c821175bab9d5637b7321ecacc5ec6636...         []
# 3     [e8951eddb19b697bc74549aa9d4f956a8be8d5cf2c7a8...         []
# 4     [e8951eddb19b697bc74549aa9d4f956a8be8d5cf2c7a8...         []
# ...                                                 ...        ...
# 5549  [9ffe3cb33bf6e114bfb5a246488e6e5bf0f7210ae5eb4...         []
# 5550  [10daf69798f9d1245cd5d85346d21b76e114b72dbee6d...         []
# 5551  [10daf69798f9d1245cd5d85346d21b76e114b72dbee6d...         []
# 5552  [72e3fb4af1fa098a599c3604fe47cedd939d0c76a59e6...         []
# 5553  [97133ae08ca7d760ae78d8b5acbe61fe72ed3953b17de...         []
#
#                  ipv4  ipv6                           dns dns_srv   port
# 0        54.220.20.40  None                          None    None   3002
# 1                None  None  relays.mainnet.stakenuts.com    None   3001
# 2                None  None           relay.zenithpool.io    None  31400
# 3        95.183.53.20  None                          None    None   6060
# 4      95.217.222.194  None                          None    None   6060
# ...               ...   ...                           ...     ...    ...
# 5549             None  None       managedrewards.ddns.net    None   5001
# 5550             None  None            relay1.bahrtec.com    None   6000
# 5551             None  None            relay2.bahrtec.com    None   6001
# 5552  217.133.194.127  None                          None    None   3001
# 5553   18.222.142.165  None                          None    None   3001
#
# [5554 rows x 23 columns]

# %%
df[['ipv4', 'ipv6', 'dns', 'dns_srv', 'port']] = df[['ipv4', 'ipv6', 'dns', 'dns_srv', 'port']].fillna(value='')

# %%
df
# Out:
#                                                 pool_id  \
# 0     pool1z5uqdk7dzdxaae5633fqfcu2eqzy3a3rgtuvy087f...
# 1     pool1pu5jlj4q9w9jlxeu370a3c9myx47md5j5m2str0na...
# 2     pool1c8k78ny3xvsfgenhf4yzvpzwgzxmz0t0um0h2xnn2...
# 3     pool1q80jjs53w0fx836n8g38gtdwr8ck5zre3da90peux...
# 4     pool1q80jjs53w0fx836n8g38gtdwr8ck5zre3da90peux...
# ...                                                 ...
# 5549  pool1hjlqkwx604reu9q2azkmqp9ek7f5yy37qz662afzl...
# 5550  pool1wj2j9zfv9mly5m7ax5fen0r8rp7tjj9uyz5gnwmyf...
# 5551  pool1wj2j9zfv9mly5m7ax5fen0r8rp7tjj9uyz5gnwmyf...
# 5552  pool178jmsy6t03udg2urvckseyync6y2jkq26haj7vxtw...
# 5553  pool1324lgsmm6aqkyeamzxjkfhsk4v9qtkr5knyza2r8l...
#
#                                                     hex  \
# 0     153806dbcd134ddee69a8c5204e38ac80448f62342f8c2...
# 1     0f292fcaa02b8b2f9b3c8f9fd8e0bb21abedb692a6d505...
# 2     c1ede3cc9133209466774d4826044e408db13d6fe6df75...
# 3     01df29429173d263c7533a22742dae19f16a08798b7a57...
# 4     01df29429173d263c7533a22742dae19f16a08798b7a57...
# ...                                                 ...
# 5549  bcbe0b38da7d479e140ae8adb004b9b79342123e00b5a5...
# 5550  749522892c2efe4a6fdd351399bc67187cb948bc20a889...
# 5551  749522892c2efe4a6fdd351399bc67187cb948bc20a889...
# 5552  f1e5b8134b7c78d42b83662d0c9093c688a9580ad5fb2f...
# 5553  8aabf4437bd7416267bb11a564de16ab0a05d874b4c82e...
#
#                                                 vrf_key  blocks_minted  \
# 0     0220a5d08adbfe9554b52d7b2993be5892ac3ff340e674...           3972
# 1     b512cc7c1a8ba689c2d8fd27adfdbac2049a3f8f95c8b8...           1731
# 2     b8ba5f7dcbf17e95781e325114da46def1fa908435a27d...             74
# 3     b75115a1e4e32a33985fc720f3715f0e99617b448fbc36...            253
# 4     b75115a1e4e32a33985fc720f3715f0e99617b448fbc36...            253
# ...                                                 ...            ...
# 5549  9e2dd26107ad95ef05522e49879f4b2285811c0eaa504f...              0
# 5550  d646e0712fd9dd18655787607970bbc643f4beca617a40...              0
# 5551  d646e0712fd9dd18655787607970bbc643f4beca617a40...              0
# 5552  b35b88a9474161da1022efe756e23d771a6a8deb541a3a...              0
# 5553  5fac976d838f1432925e44e209c5a8a7ac91f56d3b8968...              0
#
#           live_stake     live_size  live_saturation  live_delegators  \
# 0     32797569479332  1.378547e-03     4.903471e-01             3198
# 1     19363531997705  8.138880e-04     2.894987e-01              168
# 2       558085506979  2.345740e-05     8.343778e-03               15
# 3      1845839071889  7.758430e-05     2.759662e-02              717
# 4      1845839071889  7.758430e-05     2.759662e-02              717
# ...              ...           ...              ...              ...
# 5549      1000000000  4.200000e-08     1.495070e-05                1
# 5550       616723251  2.590000e-08     9.220500e-06                2
# 5551       616723251  2.590000e-08     9.220500e-06                2
# 5552       589721212  2.480000e-08     8.816800e-06                2
# 5553        43761105  1.800000e-09     6.543000e-07                2
#
#         active_stake  active_size  declared_pledge   live_pledge  margin_cost  \
# 0     16401223192227     0.001247     100000000000  572478193547        0.009
# 1     18304506933371     0.001391     510000000000  561624278408        0.049
# 2       550355739333     0.000042      50100000000  552069493858        0.000
# 3      1195539828288     0.000091     200000000000  205479488742        0.005
# 4      1195539828288     0.000091     200000000000  205479488742        0.005
# ...              ...          ...              ...           ...          ...
# 5549               0     0.000000       1000000000    1000000000        1.000
# 5550               0     0.000000        100000000     509250920        0.010
# 5551               0     0.000000        100000000     509250920        0.010
# 5552               0     0.000000        500000000     542784694        0.000
# 5553               0     0.000000        100000000             0        0.150
#
#       fixed_cost                                     reward_account  \
# 0      340000000  stake1uy89kzrdlpaz5rzu8x95r4qnlpqhd3f8mf09edjp...
# 1      340000000  stake1u98nnlkvkk23vtvf9273uq7cph5ww6u2yq2389ps...
# 2      340000000  stake1uyx0ut5wc5nmu0tacjc9pyyahdyq5ujghwljkdxr...
# 3      340000000  stake1uxxsa2rlkv728pve3ks7kn7c6v68luagdjgwa0me...
# 4      340000000  stake1uxxsa2rlkv728pve3ks7kn7c6v68luagdjgwa0me...
# ...          ...                                                ...
# 5549   500000000  stake1u95ggvstszjdwm2hmtpvcscjvne6fcamk2mqx2u3...
# 5550   340000000  stake1u8gm2glyzm0wzzlfrnzp90y4sqc46eqta5fpyqq0...
# 5551   340000000  stake1u8gm2glyzm0wzzlfrnzp90y4sqc46eqta5fpyqq0...
# 5552   340000000  stake1u9c7ypc7swj7gultpv4dh2uhs3xc2dcdm9278mp7...
# 5553   345000000  stake1u884wym0uvcetx6lmjz4xm7kyvjvhejm7m3xyggw...
#
#                                                  owners  \
# 0     [stake1uy89kzrdlpaz5rzu8x95r4qnlpqhd3f8mf09edj...
# 1     [stake1u98nnlkvkk23vtvf9273uq7cph5ww6u2yq2389p...
# 2     [stake1uyx0ut5wc5nmu0tacjc9pyyahdyq5ujghwljkdx...
# 3     [stake1uxxsa2rlkv728pve3ks7kn7c6v68luagdjgwa0m...
# 4     [stake1uxxsa2rlkv728pve3ks7kn7c6v68luagdjgwa0m...
# ...                                                 ...
# 5549  [stake1u95ggvstszjdwm2hmtpvcscjvne6fcamk2mqx2u...
# 5550  [stake1u8gm2glyzm0wzzlfrnzp90y4sqc46eqta5fpyqq...
# 5551  [stake1u8gm2glyzm0wzzlfrnzp90y4sqc46eqta5fpyqq...
# 5552  [stake1u9c7ypc7swj7gultpv4dh2uhs3xc2dcdm9278mp...
# 5553  [stake1u884wym0uvcetx6lmjz4xm7kyvjvhejm7m3xygg...
#
#                                            registration retirement  \
# 0     [841cca81da918feb9fa7257a34630eac95794be712ed3...         []
# 1     [a96c79773b7506211eb56bf94886a2face17657d1009f...         []
# 2     [37f5682e2622c821175bab9d5637b7321ecacc5ec6636...         []
# 3     [e8951eddb19b697bc74549aa9d4f956a8be8d5cf2c7a8...         []
# 4     [e8951eddb19b697bc74549aa9d4f956a8be8d5cf2c7a8...         []
# ...                                                 ...        ...
# 5549  [9ffe3cb33bf6e114bfb5a246488e6e5bf0f7210ae5eb4...         []
# 5550  [10daf69798f9d1245cd5d85346d21b76e114b72dbee6d...         []
# 5551  [10daf69798f9d1245cd5d85346d21b76e114b72dbee6d...         []
# 5552  [72e3fb4af1fa098a599c3604fe47cedd939d0c76a59e6...         []
# 5553  [97133ae08ca7d760ae78d8b5acbe61fe72ed3953b17de...         []
#
#                  ipv4 ipv6                           dns dns_srv   port
# 0        54.220.20.40                                              3002
# 1                           relays.mainnet.stakenuts.com           3001
# 2                                    relay.zenithpool.io          31400
# 3        95.183.53.20                                              6060
# 4      95.217.222.194                                              6060
# ...               ...  ...                           ...     ...    ...
# 5549                             managedrewards.ddns.net           5001
# 5550                                  relay1.bahrtec.com           6000
# 5551                                  relay2.bahrtec.com           6001
# 5552  217.133.194.127                                              3001
# 5553   18.222.142.165                                              3001
#
# [5554 rows x 23 columns]

# %%
def get_ip_host(df, outputfileName):
	
	ip_host_lst = []
	columns_list = list(df.columns)

	if type(df) != pd.DataFrame:
		raise TypeError('df must be a pandas dataframe')
	if type(outputfileName) != str:
		raise TypeError('outputfileName must be a string')


	for i in range(len(df)):
		# Raise type error if the data is not a string
		if type(df['dns'][i]) != str:
			print(df['dns'][i])
			raise TypeError('dns must be a string')

		if type(df['dns_srv'][i]) != str:
			print(df['dns_srv'][i])
			raise TypeError('dns_srv must be a string')

		if type(df['ipv4'][i]) != str:
			print(df['ipv4'][i])
			raise TypeError('ipv4 must be a string')

		if type(df['ipv6'][i]) != str:	
			print(df['ipv6'][i])
			raise TypeError('ipv6 must be a string')

		# This code maps the ip host to its pool_id as a tuple
    
		if len(df['dns'][i]) > 0 or len(df['dns'][i]) > 4:
			ip_host_lst.append(tuple((df['pool_id'][i], df['hex'][i], df['vrf_key'][i], df['blocks_minted'][i], df['live_stake'][i], df['live_size'][i], df['live_saturation'][i], df['live_delegators'][i], df['active_stake'][i], df['active_size'][i], df['declared_pledge'][i], df['live_pledge'][i], df['margin_cost'][i], df['fixed_cost'][i], df['reward_account'][i], df['owners'][i], df['registration'][i], df['retirement'][i], df['dns'][i], df['port'][i])))

		if len(df['dns_srv'][i]) > 0 or len(df['dns_srv'][i]) > 4:
			ip_host_lst.append(tuple((df['pool_id'][i], df['hex'][i], df['vrf_key'][i], df['blocks_minted'][i], df['live_stake'][i], df['live_size'][i], df['live_saturation'][i], df['live_delegators'][i], df['active_stake'][i], df['active_size'][i], df['declared_pledge'][i], df['live_pledge'][i], df['margin_cost'][i], df['fixed_cost'][i], df['reward_account'][i], df['owners'][i], df['registration'][i], df['retirement'][i], df['dns_srv'][i], df['port'][i])))
		# 	ip_host_lst.append(tuple((df['dns_srv'][i], df['port'][i], df['pool_id'][i],
		# 	df['live_stake'][i], df['delegators'][i], df['description'][i],
		# 	df['hash'][i], df['hex'][i], df['homepage'][i], df['name'][i],
		# 	df['ticker'][i], df['url'][i])))

		if len(df['ipv4'][i]) > 0 or len(df['ipv4'][i]) > 4:
			ip_host_lst.append(tuple((df['pool_id'][i], df['hex'][i], df['vrf_key'][i], df['blocks_minted'][i], df['live_stake'][i], df['live_size'][i], df['live_saturation'][i], df['live_delegators'][i], df['active_stake'][i], df['active_size'][i], df['declared_pledge'][i], df['live_pledge'][i], df['margin_cost'][i], df['fixed_cost'][i], df['reward_account'][i], df['owners'][i], df['registration'][i], df['retirement'][i], df['ipv4'][i], df['port'][i])))

		# 	ip_host_lst.append(tuple((df['ipv4'][i], df['port'][i], df['pool_id'][i],
		# 	df['live_stake'][i], df['delegators'][i], df['description'][i],
		# 	df['hash'][i], df['hex'][i], df['homepage'][i], df['name'][i],
		# 	df['ticker'][i], df['url'][i])))

		if len(df['ipv6'][i]) > 0 or len(df['ipv6'][i]) > 4:
          		ip_host_lst.append(tuple((df['pool_id'][i], df['hex'][i], df['vrf_key'][i], df['blocks_minted'][i], df['live_stake'][i], df['live_size'][i], df['live_saturation'][i], df['live_delegators'][i], df['active_stake'][i], df['active_size'][i], df['declared_pledge'][i], df['live_pledge'][i], df['margin_cost'][i], df['fixed_cost'][i], df['reward_account'][i], df['owners'][i], df['registration'][i], df['retirement'][i], df['ipv6'][i], df['port'][i])))

		# 	ip_host_lst.append(tuple((df['ipv6'][i], df['port'][i], df['pool_id'][i],
		# 	df['live_stake'][i], df['delegators'][i], df['description'][i],
		# 	df['hash'][i], df['hex'][i], df['homepage'][i], df['name'][i],
		# 	df['ticker'][i], df['url'][i])))
	
	if len(ip_host_lst) == 0:
		print('No IPs found')

	if len(ip_host_lst) != len(df):
		print('Number of rows in host lst: '+str(len(ip_host_lst)), 'Number of Rows in original df: '+str(len(df)), sep='\n')
	
	ip_host_df = pd.DataFrame(pd.Series(ip_host_lst))
	ip_host_df.columns = ['ip_host']

	
	return ip_host_df.to_csv(r''+outputfileName+'.csv', index=False)

# %%
get_ip_host(df, 'all_relays_resolved_latest')
# Out:
# Number of rows in host lst: 5558
# Number of Rows in original df: 5554

# %%
testing = pd.read_csv('all_relays_resolved_latest.csv')
testing
# Out:
#                                                 ip_host
# 0     ('pool1z5uqdk7dzdxaae5633fqfcu2eqzy3a3rgtuvy08...
# 1     ('pool1pu5jlj4q9w9jlxeu370a3c9myx47md5j5m2str0...
# 2     ('pool1c8k78ny3xvsfgenhf4yzvpzwgzxmz0t0um0h2xn...
# 3     ('pool1q80jjs53w0fx836n8g38gtdwr8ck5zre3da90pe...
# 4     ('pool1q80jjs53w0fx836n8g38gtdwr8ck5zre3da90pe...
# ...                                                 ...
# 5553  ('pool1hjlqkwx604reu9q2azkmqp9ek7f5yy37qz662af...
# 5554  ('pool1wj2j9zfv9mly5m7ax5fen0r8rp7tjj9uyz5gnwm...
# 5555  ('pool1wj2j9zfv9mly5m7ax5fen0r8rp7tjj9uyz5gnwm...
# 5556  ('pool178jmsy6t03udg2urvckseyync6y2jkq26haj7vx...
# 5557  ('pool1324lgsmm6aqkyeamzxjkfhsk4v9qtkr5knyza2r...
#
# [5558 rows x 1 columns]

# %%
# Need to convert the all_relays.csv data to a tuple object from the string
# we will use literal_eval to convert the string to a tuple

import ast

testing['ip_host_tuple'] = testing['ip_host'].apply(ast.literal_eval)
testing
# Out:
#                                                 ip_host  \
# 0     ('pool1z5uqdk7dzdxaae5633fqfcu2eqzy3a3rgtuvy08...
# 1     ('pool1pu5jlj4q9w9jlxeu370a3c9myx47md5j5m2str0...
# 2     ('pool1c8k78ny3xvsfgenhf4yzvpzwgzxmz0t0um0h2xn...
# 3     ('pool1q80jjs53w0fx836n8g38gtdwr8ck5zre3da90pe...
# 4     ('pool1q80jjs53w0fx836n8g38gtdwr8ck5zre3da90pe...
# ...                                                 ...
# 5553  ('pool1hjlqkwx604reu9q2azkmqp9ek7f5yy37qz662af...
# 5554  ('pool1wj2j9zfv9mly5m7ax5fen0r8rp7tjj9uyz5gnwm...
# 5555  ('pool1wj2j9zfv9mly5m7ax5fen0r8rp7tjj9uyz5gnwm...
# 5556  ('pool178jmsy6t03udg2urvckseyync6y2jkq26haj7vx...
# 5557  ('pool1324lgsmm6aqkyeamzxjkfhsk4v9qtkr5knyza2r...
#
#                                           ip_host_tuple
# 0     (pool1z5uqdk7dzdxaae5633fqfcu2eqzy3a3rgtuvy087...
# 1     (pool1pu5jlj4q9w9jlxeu370a3c9myx47md5j5m2str0n...
# 2     (pool1c8k78ny3xvsfgenhf4yzvpzwgzxmz0t0um0h2xnn...
# 3     (pool1q80jjs53w0fx836n8g38gtdwr8ck5zre3da90peu...
# 4     (pool1q80jjs53w0fx836n8g38gtdwr8ck5zre3da90peu...
# ...                                                 ...
# 5553  (pool1hjlqkwx604reu9q2azkmqp9ek7f5yy37qz662afz...
# 5554  (pool1wj2j9zfv9mly5m7ax5fen0r8rp7tjj9uyz5gnwmy...
# 5555  (pool1wj2j9zfv9mly5m7ax5fen0r8rp7tjj9uyz5gnwmy...
# 5556  (pool178jmsy6t03udg2urvckseyync6y2jkq26haj7vxt...
# 5557  (pool1324lgsmm6aqkyeamzxjkfhsk4v9qtkr5knyza2r8...
#
# [5558 rows x 2 columns]

# %%
# Let's make a function to resolve hostnames to IP addresses
import dns.resolver
def resolve_hostname(hostname):
	try:
		ip = dns.resolver.resolve(hostname, 'A')
		return ip[0].to_text()
	except:
		return ''

# %%
new_df = pd.DataFrame()
new_df['pool_id'], new_df['hex'], new_df['vrf_key'], new_df['blocks_minted'], new_df['live_stake'], new_df['live_size'], new_df['live_saturation'], new_df['live_delegators'], new_df['active_stake'], new_df['active_size'], new_df['declared_pledge'], new_df['live_pledge'], new_df['margin_cost'], new_df['fixed_cost'], new_df['reward_account'], new_df['owners'], new_df['registration'], new_df['retirement'],new_df['ip_host'], new_df['port'] = testing.ip_host_tuple.str
new_df
# Out:
# /var/folders/qm/qxx0f2_j4pd9p5_p096pjflw0000gn/T/ipykernel_89793/2001426236.py:2: FutureWarning: Columnar iteration over characters will be deprecated in future releases.
#   new_df['pool_id'], new_df['hex'], new_df['vrf_key'], new_df['blocks_minted'], new_df['live_stake'], new_df['live_size'], new_df['live_saturation'], new_df['live_delegators'], new_df['active_stake'], new_df['active_size'], new_df['declared_pledge'], new_df['live_pledge'], new_df['margin_cost'], new_df['fixed_cost'], new_df['reward_account'], new_df['owners'], new_df['registration'], new_df['retirement'],new_df['ip_host'], new_df['port'] = testing.ip_host_tuple.str
#                                                 pool_id  \
# 0     pool1z5uqdk7dzdxaae5633fqfcu2eqzy3a3rgtuvy087f...
# 1     pool1pu5jlj4q9w9jlxeu370a3c9myx47md5j5m2str0na...
# 2     pool1c8k78ny3xvsfgenhf4yzvpzwgzxmz0t0um0h2xnn2...
# 3     pool1q80jjs53w0fx836n8g38gtdwr8ck5zre3da90peux...
# 4     pool1q80jjs53w0fx836n8g38gtdwr8ck5zre3da90peux...
# ...                                                 ...
# 5553  pool1hjlqkwx604reu9q2azkmqp9ek7f5yy37qz662afzl...
# 5554  pool1wj2j9zfv9mly5m7ax5fen0r8rp7tjj9uyz5gnwmyf...
# 5555  pool1wj2j9zfv9mly5m7ax5fen0r8rp7tjj9uyz5gnwmyf...
# 5556  pool178jmsy6t03udg2urvckseyync6y2jkq26haj7vxtw...
# 5557  pool1324lgsmm6aqkyeamzxjkfhsk4v9qtkr5knyza2r8l...
#
#                                                     hex  \
# 0     153806dbcd134ddee69a8c5204e38ac80448f62342f8c2...
# 1     0f292fcaa02b8b2f9b3c8f9fd8e0bb21abedb692a6d505...
# 2     c1ede3cc9133209466774d4826044e408db13d6fe6df75...
# 3     01df29429173d263c7533a22742dae19f16a08798b7a57...
# 4     01df29429173d263c7533a22742dae19f16a08798b7a57...
# ...                                                 ...
# 5553  bcbe0b38da7d479e140ae8adb004b9b79342123e00b5a5...
# 5554  749522892c2efe4a6fdd351399bc67187cb948bc20a889...
# 5555  749522892c2efe4a6fdd351399bc67187cb948bc20a889...
# 5556  f1e5b8134b7c78d42b83662d0c9093c688a9580ad5fb2f...
# 5557  8aabf4437bd7416267bb11a564de16ab0a05d874b4c82e...
#
#                                                 vrf_key  blocks_minted  \
# 0     0220a5d08adbfe9554b52d7b2993be5892ac3ff340e674...           3972
# 1     b512cc7c1a8ba689c2d8fd27adfdbac2049a3f8f95c8b8...           1731
# 2     b8ba5f7dcbf17e95781e325114da46def1fa908435a27d...             74
# 3     b75115a1e4e32a33985fc720f3715f0e99617b448fbc36...            253
# 4     b75115a1e4e32a33985fc720f3715f0e99617b448fbc36...            253
# ...                                                 ...            ...
# 5553  9e2dd26107ad95ef05522e49879f4b2285811c0eaa504f...              0
# 5554  d646e0712fd9dd18655787607970bbc643f4beca617a40...              0
# 5555  d646e0712fd9dd18655787607970bbc643f4beca617a40...              0
# 5556  b35b88a9474161da1022efe756e23d771a6a8deb541a3a...              0
# 5557  5fac976d838f1432925e44e209c5a8a7ac91f56d3b8968...              0
#
#           live_stake     live_size  live_saturation  live_delegators  \
# 0     32797569479332  1.378547e-03     4.903471e-01             3198
# 1     19363531997705  8.138880e-04     2.894987e-01              168
# 2       558085506979  2.345740e-05     8.343778e-03               15
# 3      1845839071889  7.758430e-05     2.759662e-02              717
# 4      1845839071889  7.758430e-05     2.759662e-02              717
# ...              ...           ...              ...              ...
# 5553      1000000000  4.200000e-08     1.495070e-05                1
# 5554       616723251  2.590000e-08     9.220500e-06                2
# 5555       616723251  2.590000e-08     9.220500e-06                2
# 5556       589721212  2.480000e-08     8.816800e-06                2
# 5557        43761105  1.800000e-09     6.543000e-07                2
#
#         active_stake  active_size  declared_pledge   live_pledge  margin_cost  \
# 0     16401223192227     0.001247     100000000000  572478193547        0.009
# 1     18304506933371     0.001391     510000000000  561624278408        0.049
# 2       550355739333     0.000042      50100000000  552069493858        0.000
# 3      1195539828288     0.000091     200000000000  205479488742        0.005
# 4      1195539828288     0.000091     200000000000  205479488742        0.005
# ...              ...          ...              ...           ...          ...
# 5553               0     0.000000       1000000000    1000000000        1.000
# 5554               0     0.000000        100000000     509250920        0.010
# 5555               0     0.000000        100000000     509250920        0.010
# 5556               0     0.000000        500000000     542784694        0.000
# 5557               0     0.000000        100000000             0        0.150
#
#       fixed_cost                                     reward_account  \
# 0      340000000  stake1uy89kzrdlpaz5rzu8x95r4qnlpqhd3f8mf09edjp...
# 1      340000000  stake1u98nnlkvkk23vtvf9273uq7cph5ww6u2yq2389ps...
# 2      340000000  stake1uyx0ut5wc5nmu0tacjc9pyyahdyq5ujghwljkdxr...
# 3      340000000  stake1uxxsa2rlkv728pve3ks7kn7c6v68luagdjgwa0me...
# 4      340000000  stake1uxxsa2rlkv728pve3ks7kn7c6v68luagdjgwa0me...
# ...          ...                                                ...
# 5553   500000000  stake1u95ggvstszjdwm2hmtpvcscjvne6fcamk2mqx2u3...
# 5554   340000000  stake1u8gm2glyzm0wzzlfrnzp90y4sqc46eqta5fpyqq0...
# 5555   340000000  stake1u8gm2glyzm0wzzlfrnzp90y4sqc46eqta5fpyqq0...
# 5556   340000000  stake1u9c7ypc7swj7gultpv4dh2uhs3xc2dcdm9278mp7...
# 5557   345000000  stake1u884wym0uvcetx6lmjz4xm7kyvjvhejm7m3xyggw...
#
#                                                  owners  \
# 0     [stake1uy89kzrdlpaz5rzu8x95r4qnlpqhd3f8mf09edj...
# 1     [stake1u98nnlkvkk23vtvf9273uq7cph5ww6u2yq2389p...
# 2     [stake1uyx0ut5wc5nmu0tacjc9pyyahdyq5ujghwljkdx...
# 3     [stake1uxxsa2rlkv728pve3ks7kn7c6v68luagdjgwa0m...
# 4     [stake1uxxsa2rlkv728pve3ks7kn7c6v68luagdjgwa0m...
# ...                                                 ...
# 5553  [stake1u95ggvstszjdwm2hmtpvcscjvne6fcamk2mqx2u...
# 5554  [stake1u8gm2glyzm0wzzlfrnzp90y4sqc46eqta5fpyqq...
# 5555  [stake1u8gm2glyzm0wzzlfrnzp90y4sqc46eqta5fpyqq...
# 5556  [stake1u9c7ypc7swj7gultpv4dh2uhs3xc2dcdm9278mp...
# 5557  [stake1u884wym0uvcetx6lmjz4xm7kyvjvhejm7m3xygg...
#
#                                            registration retirement  \
# 0     [841cca81da918feb9fa7257a34630eac95794be712ed3...         []
# 1     [a96c79773b7506211eb56bf94886a2face17657d1009f...         []
# 2     [37f5682e2622c821175bab9d5637b7321ecacc5ec6636...         []
# 3     [e8951eddb19b697bc74549aa9d4f956a8be8d5cf2c7a8...         []
# 4     [e8951eddb19b697bc74549aa9d4f956a8be8d5cf2c7a8...         []
# ...                                                 ...        ...
# 5553  [9ffe3cb33bf6e114bfb5a246488e6e5bf0f7210ae5eb4...         []
# 5554  [10daf69798f9d1245cd5d85346d21b76e114b72dbee6d...         []
# 5555  [10daf69798f9d1245cd5d85346d21b76e114b72dbee6d...         []
# 5556  [72e3fb4af1fa098a599c3604fe47cedd939d0c76a59e6...         []
# 5557  [97133ae08ca7d760ae78d8b5acbe61fe72ed3953b17de...         []
#
#                            ip_host   port
# 0                     54.220.20.40   3002
# 1     relays.mainnet.stakenuts.com   3001
# 2              relay.zenithpool.io  31400
# 3                     95.183.53.20   6060
# 4                   95.217.222.194   6060
# ...                            ...    ...
# 5553       managedrewards.ddns.net   5001
# 5554            relay1.bahrtec.com   6000
# 5555            relay2.bahrtec.com   6001
# 5556               217.133.194.127   3001
# 5557                18.222.142.165   3001
#
# [5558 rows x 20 columns]

# %%
new_df['resolved_ip'] = new_df['ip_host'].apply(resolve_hostname)

# %%
# sprinkle some magic to get the resolved IPs and the IPs in ip_host into a single column
for i in range(len(new_df)):
	if len(new_df['resolved_ip'][i]) == 0:
		new_df['resolved_ip'][i] = new_df['ip_host'][i]

# %%
new_df
# Out:
#                                                 pool_id  \
# 0     pool1z5uqdk7dzdxaae5633fqfcu2eqzy3a3rgtuvy087f...
# 1     pool1pu5jlj4q9w9jlxeu370a3c9myx47md5j5m2str0na...
# 2     pool1c8k78ny3xvsfgenhf4yzvpzwgzxmz0t0um0h2xnn2...
# 3     pool1q80jjs53w0fx836n8g38gtdwr8ck5zre3da90peux...
# 4     pool1q80jjs53w0fx836n8g38gtdwr8ck5zre3da90peux...
# ...                                                 ...
# 5553  pool1hjlqkwx604reu9q2azkmqp9ek7f5yy37qz662afzl...
# 5554  pool1wj2j9zfv9mly5m7ax5fen0r8rp7tjj9uyz5gnwmyf...
# 5555  pool1wj2j9zfv9mly5m7ax5fen0r8rp7tjj9uyz5gnwmyf...
# 5556  pool178jmsy6t03udg2urvckseyync6y2jkq26haj7vxtw...
# 5557  pool1324lgsmm6aqkyeamzxjkfhsk4v9qtkr5knyza2r8l...
#
#                                                     hex  \
# 0     153806dbcd134ddee69a8c5204e38ac80448f62342f8c2...
# 1     0f292fcaa02b8b2f9b3c8f9fd8e0bb21abedb692a6d505...
# 2     c1ede3cc9133209466774d4826044e408db13d6fe6df75...
# 3     01df29429173d263c7533a22742dae19f16a08798b7a57...
# 4     01df29429173d263c7533a22742dae19f16a08798b7a57...
# ...                                                 ...
# 5553  bcbe0b38da7d479e140ae8adb004b9b79342123e00b5a5...
# 5554  749522892c2efe4a6fdd351399bc67187cb948bc20a889...
# 5555  749522892c2efe4a6fdd351399bc67187cb948bc20a889...
# 5556  f1e5b8134b7c78d42b83662d0c9093c688a9580ad5fb2f...
# 5557  8aabf4437bd7416267bb11a564de16ab0a05d874b4c82e...
#
#                                                 vrf_key  blocks_minted  \
# 0     0220a5d08adbfe9554b52d7b2993be5892ac3ff340e674...           3972
# 1     b512cc7c1a8ba689c2d8fd27adfdbac2049a3f8f95c8b8...           1731
# 2     b8ba5f7dcbf17e95781e325114da46def1fa908435a27d...             74
# 3     b75115a1e4e32a33985fc720f3715f0e99617b448fbc36...            253
# 4     b75115a1e4e32a33985fc720f3715f0e99617b448fbc36...            253
# ...                                                 ...            ...
# 5553  9e2dd26107ad95ef05522e49879f4b2285811c0eaa504f...              0
# 5554  d646e0712fd9dd18655787607970bbc643f4beca617a40...              0
# 5555  d646e0712fd9dd18655787607970bbc643f4beca617a40...              0
# 5556  b35b88a9474161da1022efe756e23d771a6a8deb541a3a...              0
# 5557  5fac976d838f1432925e44e209c5a8a7ac91f56d3b8968...              0
#
#           live_stake     live_size  live_saturation  live_delegators  \
# 0     32797569479332  1.378547e-03     4.903471e-01             3198
# 1     19363531997705  8.138880e-04     2.894987e-01              168
# 2       558085506979  2.345740e-05     8.343778e-03               15
# 3      1845839071889  7.758430e-05     2.759662e-02              717
# 4      1845839071889  7.758430e-05     2.759662e-02              717
# ...              ...           ...              ...              ...
# 5553      1000000000  4.200000e-08     1.495070e-05                1
# 5554       616723251  2.590000e-08     9.220500e-06                2
# 5555       616723251  2.590000e-08     9.220500e-06                2
# 5556       589721212  2.480000e-08     8.816800e-06                2
# 5557        43761105  1.800000e-09     6.543000e-07                2
#
#         active_stake  active_size  declared_pledge   live_pledge  margin_cost  \
# 0     16401223192227     0.001247     100000000000  572478193547        0.009
# 1     18304506933371     0.001391     510000000000  561624278408        0.049
# 2       550355739333     0.000042      50100000000  552069493858        0.000
# 3      1195539828288     0.000091     200000000000  205479488742        0.005
# 4      1195539828288     0.000091     200000000000  205479488742        0.005
# ...              ...          ...              ...           ...          ...
# 5553               0     0.000000       1000000000    1000000000        1.000
# 5554               0     0.000000        100000000     509250920        0.010
# 5555               0     0.000000        100000000     509250920        0.010
# 5556               0     0.000000        500000000     542784694        0.000
# 5557               0     0.000000        100000000             0        0.150
#
#       fixed_cost                                     reward_account  \
# 0      340000000  stake1uy89kzrdlpaz5rzu8x95r4qnlpqhd3f8mf09edjp...
# 1      340000000  stake1u98nnlkvkk23vtvf9273uq7cph5ww6u2yq2389ps...
# 2      340000000  stake1uyx0ut5wc5nmu0tacjc9pyyahdyq5ujghwljkdxr...
# 3      340000000  stake1uxxsa2rlkv728pve3ks7kn7c6v68luagdjgwa0me...
# 4      340000000  stake1uxxsa2rlkv728pve3ks7kn7c6v68luagdjgwa0me...
# ...          ...                                                ...
# 5553   500000000  stake1u95ggvstszjdwm2hmtpvcscjvne6fcamk2mqx2u3...
# 5554   340000000  stake1u8gm2glyzm0wzzlfrnzp90y4sqc46eqta5fpyqq0...
# 5555   340000000  stake1u8gm2glyzm0wzzlfrnzp90y4sqc46eqta5fpyqq0...
# 5556   340000000  stake1u9c7ypc7swj7gultpv4dh2uhs3xc2dcdm9278mp7...
# 5557   345000000  stake1u884wym0uvcetx6lmjz4xm7kyvjvhejm7m3xyggw...
#
#                                                  owners  \
# 0     [stake1uy89kzrdlpaz5rzu8x95r4qnlpqhd3f8mf09edj...
# 1     [stake1u98nnlkvkk23vtvf9273uq7cph5ww6u2yq2389p...
# 2     [stake1uyx0ut5wc5nmu0tacjc9pyyahdyq5ujghwljkdx...
# 3     [stake1uxxsa2rlkv728pve3ks7kn7c6v68luagdjgwa0m...
# 4     [stake1uxxsa2rlkv728pve3ks7kn7c6v68luagdjgwa0m...
# ...                                                 ...
# 5553  [stake1u95ggvstszjdwm2hmtpvcscjvne6fcamk2mqx2u...
# 5554  [stake1u8gm2glyzm0wzzlfrnzp90y4sqc46eqta5fpyqq...
# 5555  [stake1u8gm2glyzm0wzzlfrnzp90y4sqc46eqta5fpyqq...
# 5556  [stake1u9c7ypc7swj7gultpv4dh2uhs3xc2dcdm9278mp...
# 5557  [stake1u884wym0uvcetx6lmjz4xm7kyvjvhejm7m3xygg...
#
#                                            registration retirement  \
# 0     [841cca81da918feb9fa7257a34630eac95794be712ed3...         []
# 1     [a96c79773b7506211eb56bf94886a2face17657d1009f...         []
# 2     [37f5682e2622c821175bab9d5637b7321ecacc5ec6636...         []
# 3     [e8951eddb19b697bc74549aa9d4f956a8be8d5cf2c7a8...         []
# 4     [e8951eddb19b697bc74549aa9d4f956a8be8d5cf2c7a8...         []
# ...                                                 ...        ...
# 5553  [9ffe3cb33bf6e114bfb5a246488e6e5bf0f7210ae5eb4...         []
# 5554  [10daf69798f9d1245cd5d85346d21b76e114b72dbee6d...         []
# 5555  [10daf69798f9d1245cd5d85346d21b76e114b72dbee6d...         []
# 5556  [72e3fb4af1fa098a599c3604fe47cedd939d0c76a59e6...         []
# 5557  [97133ae08ca7d760ae78d8b5acbe61fe72ed3953b17de...         []
#
#                            ip_host   port      resolved_ip
# 0                     54.220.20.40   3002     54.220.20.40
# 1     relays.mainnet.stakenuts.com   3001   199.247.23.219
# 2              relay.zenithpool.io  31400  129.146.210.203
# 3                     95.183.53.20   6060     95.183.53.20
# 4                   95.217.222.194   6060   95.217.222.194
# ...                            ...    ...              ...
# 5553       managedrewards.ddns.net   5001    77.58.244.133
# 5554            relay1.bahrtec.com   6000   217.91.113.138
# 5555            relay2.bahrtec.com   6001   217.91.113.138
# 5556               217.133.194.127   3001  217.133.194.127
# 5557                18.222.142.165   3001   18.222.142.165
#
# [5558 rows x 21 columns]
